# %% [markdown]
# # Pandas Practice Workbook — Netflix Dataset (125 Questions)
# **Prepared by Nageshwor Sharma** · Dataset: `netflix_clean.csv`
#
# **Columns:** `show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, descriptions.
#
#
# | Section | Topic | Questions |
# |---------|-------|-----------|
# | A | First Analysis of Data | 15 |
# | B | Selection with `[]`, `.loc`, `.iloc` | 25 |
# | C | Conditions (with `.loc`) | 20 |
# | D | Sorting | 10 |
# | E | Updating Data | 15 |
# | F | GroupBy | 20 |
# | G | Cleaning | 20 |
# | **Total** | | **125** |

# %% [markdown]
# ## Section A — First Analysis of Data (Q1–Q15)

# %% [markdown]
# #### Q1. Load the dataset into a DataFrame called `df` and display the first 5 rows.

# %%
import pandas as pd
df = pd.read_csv("/content/netflix_clean.csv")
df
# Out:
#     show_id     type                    title            director  \
# 0        s1    Movie         The Silent Storm  Guillermo del Toro
# 1        s2    Movie     The Forgotten Empire       Takashi Miike
# 2        s3    Movie       The Secret Whisper   Quentin Tarantino
# 3        s4    Movie        The Wild Symphony       David Fincher
# 4        s5    Movie         The Secret Storm                 NaN
# ..      ...      ...                      ...                 ...
# 545    s546    Movie         The Silent Dream                 NaN
# 546    s547    Movie   The Forgotten Protocol   Quentin Tarantino
# 547    s548    Movie  The Infinite Chronicles       James Cameron
# 548    s549    Movie         The Rising Truth        Bong Joon-ho
# 549    s550  TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                   cast         country  \
# 0                                       Shah Rukh Khan          Mexico
# 1                                       Lupita Nyong'o         Germany
# 2                                                  NaN          France
# 3    Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                                  NaN  United Kingdom
# ..                                                 ...             ...
# 545                    Leonardo DiCaprio, Song Kang-ho          Canada
# 546  Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# 547  Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# 548                                       Song Kang-ho   United States
# 549              Timothée Chalamet, Scarlett Johansson   United States
#
#              date_added  release_year rating   duration  \
# 0     February 11, 2021          1995  TV-14     74 min
# 1      January 14, 2020          2007  PG-13    167 min
# 2      October 08, 2021          2006  PG-13    163 min
# 3     November 23, 2015          2004      R    118 min
# 4    September 29, 2017          2000  TV-PG    118 min
# ..                  ...           ...    ...        ...
# 545   February 21, 2024          2007  TV-MA     75 min
# 546     August 08, 2022          1998  TV-MA     92 min
# 547   November 29, 2021          1997  NC-17    100 min
# 548   February 18, 2023          2018  TV-MA     87 min
# 549       June 16, 2022          2005   TV-G  6 Seasons
#
#                                              listed_in  \
# 0                                   Action & Adventure
# 1                               International TV Shows
# 2                     Romantic TV Shows, Documentaries
# 3                            Anime Series, TV Comedies
# 4                     Romantic TV Shows, Horror Movies
# ..                                                 ...
# 545                                    Romantic Movies
# 546          TV Dramas, Docuseries, Action & Adventure
# 547  International TV Shows, Horror Movies, Action ...
# 548                                TV Dramas, Comedies
# 549          Horror Movies, Crime TV Shows, Reality TV
#
#                                            description
# 0    When an unexpected event turns their life upsi...
# 1    An in-depth exploration of human emotions, sec...
# 2    In a race against time, a dedicated team unrav...
# 3    When an unexpected event turns their life upsi...
# 4    Dark forces emerge as secrets long buried fina...
# ..                                                 ...
# 545  In a race against time, a dedicated team unrav...
# 546  An in-depth exploration of human emotions, sec...
# 547  A compelling narrative following characters as...
# 548  A heartwarming story of friendship, love, and ...
# 549  An in-depth exploration of human emotions, sec...
#
# [550 rows x 12 columns]

# %% [markdown]
# #### Q2. Display the **last 7 rows** of the DataFrame.

# %%
df.tail(7)
# Out:
#     show_id     type                    title            director  \
# 543    s544    Movie       The Midnight Heart  Guillermo del Toro
# 544    s545  TV Show      The Eternal Horizon                 NaN
# 545    s546    Movie         The Silent Dream                 NaN
# 546    s547    Movie   The Forgotten Protocol   Quentin Tarantino
# 547    s548    Movie  The Infinite Chronicles       James Cameron
# 548    s549    Movie         The Rising Truth        Bong Joon-ho
# 549    s550  TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                   cast        country  \
# 543                      Scarlett Johansson, Tom Hanks    South Korea
# 544  Viola Davis, Timothée Chalamet, Omar Sy, Ana d...         Canada
# 545                    Leonardo DiCaprio, Song Kang-ho         Canada
# 546  Daniel Kaluuya, Priyanka Chopra, Mahershala Al...         Mexico
# 547  Ana de Armas, Pedro Pascal, Scarlett Johansson...  United States
# 548                                       Song Kang-ho  United States
# 549              Timothée Chalamet, Scarlett Johansson  United States
#
#             date_added  release_year rating   duration  \
# 543     March 01, 2015          2011      G    157 min
# 544      June 07, 2019          2017  TV-MA  2 Seasons
# 545  February 21, 2024          2007  TV-MA     75 min
# 546    August 08, 2022          1998  TV-MA     92 min
# 547  November 29, 2021          1997  NC-17    100 min
# 548  February 18, 2023          2018  TV-MA     87 min
# 549      June 16, 2022          2005   TV-G  6 Seasons
#
#                                              listed_in  \
# 543   Action & Adventure, Horror Movies, Documentaries
# 544                                      Documentaries
# 545                                    Romantic Movies
# 546          TV Dramas, Docuseries, Action & Adventure
# 547  International TV Shows, Horror Movies, Action ...
# 548                                TV Dramas, Comedies
# 549          Horror Movies, Crime TV Shows, Reality TV
#
#                                            description
# 543  A humorous and insightful look into modern rel...
# 544  An in-depth exploration of human emotions, sec...
# 545  In a race against time, a dedicated team unrav...
# 546  An in-depth exploration of human emotions, sec...
# 547  A compelling narrative following characters as...
# 548  A heartwarming story of friendship, love, and ...
# 549  An in-depth exploration of human emotions, sec...

# %% [markdown]
# #### Q3. How many rows and columns does the dataset have?

# %%
df.shape
# Out:
# (550, 12)

# %% [markdown]
# ###The dataset has 550 rows and 12 columns.

# %% [markdown]
# #### Q4. Display the names of all columns.

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #### Q5. Use `info()` — which columns have missing values, and what is the data type of each column?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       550 non-null    object
#  1   type          550 non-null    object
#  2   title         550 non-null    object
#  3   director      393 non-null    object
#  4   cast          449 non-null    object
#  5   country       522 non-null    object
#  6   date_added    540 non-null    object
#  7   release_year  550 non-null    int64
#  8   rating        550 non-null    object
#  9   duration      550 non-null    object
#  10  listed_in     550 non-null    object
#  11  description   550 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 51.7+ KB

# %% [markdown]
# #### Q6. Use `describe()` on the numeric columns. What is the minimum and maximum `release_year`?

# %%
df.describe()
# Out:
#        release_year
# count    550.000000
# mean    2008.121818
# std        9.675504
# min     1990.000000
# 25%     2000.000000
# 50%     2008.000000
# 75%     2017.000000
# max     2024.000000

# %% [markdown]
# ###The minimum release year is 1990 and maximom release year is 2024

# %% [markdown]
# #### Q7. Use `describe(include="object")` on the text columns. Which value appears most often in the `type` column?

# %%
# Your answer here
df[['type']].describe(include="object")
# Out:
#          type
# count     550
# unique      2
# top     Movie
# freq      397

# %% [markdown]
# ###In type column, Movie is most appeared value which is 397 times.

# %% [markdown]
# #### Q8. Count the missing values in **every** column with one command.

# %%
df.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        157
# cast            101
# country          28
# date_added       10
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# #### Q9. Which single column has the **most** missing values?

# %%
df.isna().sum().idxmax()
# Out:
# 'director'

# %% [markdown]
# ###Director column has most missing values.

# %% [markdown]
# #### Q10. How many **unique** values are in the `rating` column? Display them.

# %%
df.rating.nunique()
# Out:
# 11

# %% [markdown]
# ###There are 11 unique values in rating column

# %% [markdown]
# #### Q11. Show 5 **random** rows using `sample()`.

# %%
df.sample(5)
# Out:
#     show_id     type                   title          director  \
# 490    s491    Movie      The Broken Promise      Ava DuVernay
# 354    s355    Movie       The Shadow Valley   Martin Scorsese
# 519    s520  TV Show       The Dark Protocol               NaN
# 232    s233    Movie    The Eternal Frontier  Denis Villeneuve
# 152    s153    Movie  The Forgotten Symphony     James Cameron
#
#                                                   cast         country  \
# 490  Daniel Kaluuya, Tom Hanks, Zendaya, Margot Robbie  United Kingdom
# 354                                     Mahershala Ali          France
# 519                                                NaN          Brazil
# 232         Zendaya, Denzel Washington, Shah Rukh Khan          Mexico
# 152                    Leonardo DiCaprio, Ana de Armas           Spain
#
#             date_added  release_year rating   duration  \
# 490     April 16, 2024          2016      R     81 min
# 354   January 10, 2022          2024     PG    143 min
# 519  December 30, 2021          2003  TV-14  4 Seasons
# 232   October 24, 2019          2020  TV-14     70 min
# 152  December 28, 2018          2014  TV-14     93 min
#
#                                              listed_in  \
# 490                             International TV Shows
# 354           Crime TV Shows, Thrillers, Documentaries
# 519         TV Dramas, Crime TV Shows, Romantic Movies
# 232                                  Romantic TV Shows
# 152  TV Action & Adventure, Crime TV Shows, Action ...
#
#                                            description
# 490  When an unexpected event turns their life upsi...
# 354  A humorous and insightful look into modern rel...
# 519  In a race against time, a dedicated team unrav...
# 232  When an unexpected event turns their life upsi...
# 152  A humorous and insightful look into modern rel...

# %% [markdown]
# #### Q12. What is the memory usage of the DataFrame? (hint: `info()` or `memory_usage()`)

# %%
df.memory_usage()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       550 non-null    object
#  1   type          550 non-null    object
#  2   title         550 non-null    object
#  3   director      393 non-null    object
#  4   cast          449 non-null    object
#  5   country       522 non-null    object
#  6   date_added    540 non-null    object
#  7   release_year  550 non-null    int64
#  8   rating        550 non-null    object
#  9   duration      550 non-null    object
#  10  listed_in     550 non-null    object
#  11  description   550 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 51.7+ KB

# %% [markdown]
# #### Q13. Display the data type of only the `release_year` column.

# %%
df[['release_year']].dtypes
# Out:
# release_year    int64
# dtype: object

# %% [markdown]
# #### Q14. Count how many titles are of each `type` using `value_counts()`.

# %%
df[['type']].value_counts()
# Out:
# type
# Movie      397
# TV Show    153
# Name: count, dtype: int64

# %% [markdown]
# #### Q15. Check: does the dataset contain any **fully duplicated** rows?

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 545    False
# 546    False
# 547    False
# 548    False
# 549    False
# Length: 550, dtype: bool

# %% [markdown]
# ## Section B — Selection with `[]`, `.loc`, `.iloc` (Q16–Q40)
# *(Q16–Q30: default 0,1,2,... index · Q31–Q40: after `set_index("show_id")`)*

# %%
df
# Out:
#     show_id     type                    title            director  \
# 0        s1    Movie         The Silent Storm  Guillermo del Toro
# 1        s2    Movie     The Forgotten Empire       Takashi Miike
# 2        s3    Movie       The Secret Whisper   Quentin Tarantino
# 3        s4    Movie        The Wild Symphony       David Fincher
# 4        s5    Movie         The Secret Storm                 NaN
# ..      ...      ...                      ...                 ...
# 545    s546    Movie         The Silent Dream                 NaN
# 546    s547    Movie   The Forgotten Protocol   Quentin Tarantino
# 547    s548    Movie  The Infinite Chronicles       James Cameron
# 548    s549    Movie         The Rising Truth        Bong Joon-ho
# 549    s550  TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                   cast         country  \
# 0                                       Shah Rukh Khan          Mexico
# 1                                       Lupita Nyong'o         Germany
# 2                                                  NaN          France
# 3    Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                                  NaN  United Kingdom
# ..                                                 ...             ...
# 545                    Leonardo DiCaprio, Song Kang-ho          Canada
# 546  Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# 547  Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# 548                                       Song Kang-ho   United States
# 549              Timothée Chalamet, Scarlett Johansson   United States
#
#              date_added  release_year rating   duration  \
# 0     February 11, 2021          1995  TV-14     74 min
# 1      January 14, 2020          2007  PG-13    167 min
# 2      October 08, 2021          2006  PG-13    163 min
# 3     November 23, 2015          2004      R    118 min
# 4    September 29, 2017          2000  TV-PG    118 min
# ..                  ...           ...    ...        ...
# 545   February 21, 2024          2007  TV-MA     75 min
# 546     August 08, 2022          1998  TV-MA     92 min
# 547   November 29, 2021          1997  NC-17    100 min
# 548   February 18, 2023          2018  TV-MA     87 min
# 549       June 16, 2022          2005   TV-G  6 Seasons
#
#                                              listed_in  \
# 0                                   Action & Adventure
# 1                               International TV Shows
# 2                     Romantic TV Shows, Documentaries
# 3                            Anime Series, TV Comedies
# 4                     Romantic TV Shows, Horror Movies
# ..                                                 ...
# 545                                    Romantic Movies
# 546          TV Dramas, Docuseries, Action & Adventure
# 547  International TV Shows, Horror Movies, Action ...
# 548                                TV Dramas, Comedies
# 549          Horror Movies, Crime TV Shows, Reality TV
#
#                                            description
# 0    When an unexpected event turns their life upsi...
# 1    An in-depth exploration of human emotions, sec...
# 2    In a race against time, a dedicated team unrav...
# 3    When an unexpected event turns their life upsi...
# 4    Dark forces emerge as secrets long buried fina...
# ..                                                 ...
# 545  In a race against time, a dedicated team unrav...
# 546  An in-depth exploration of human emotions, sec...
# 547  A compelling narrative following characters as...
# 548  A heartwarming story of friendship, love, and ...
# 549  An in-depth exploration of human emotions, sec...
#
# [550 rows x 12 columns]

# %% [markdown]
# #### Q16. Select the `title` column as a **Series**.

# %%
df.iloc[:,2]
# Out:
# 0             The Silent Storm
# 1         The Forgotten Empire
# 2           The Secret Whisper
# 3            The Wild Symphony
# 4             The Secret Storm
#                 ...
# 545           The Silent Dream
# 546     The Forgotten Protocol
# 547    The Infinite Chronicles
# 548           The Rising Truth
# 549           The Velvet Truth
# Name: title, Length: 550, dtype: object

# %% [markdown]
# #### Q17. Select the `title` column as a **DataFrame** (hint: double brackets).

# %%
df.iloc[:,[2]]
# Out:
#                        title
# 0           The Silent Storm
# 1       The Forgotten Empire
# 2         The Secret Whisper
# 3          The Wild Symphony
# 4           The Secret Storm
# ..                       ...
# 545         The Silent Dream
# 546   The Forgotten Protocol
# 547  The Infinite Chronicles
# 548         The Rising Truth
# 549         The Velvet Truth
#
# [550 rows x 1 columns]

# %% [markdown]
# #### Q18. Select the columns `title`, `type`, and `country` together.

# %%
df.head(1)
# Out:
#   show_id   type             title            director            cast  \
# 0      s1  Movie  The Silent Storm  Guillermo del Toro  Shah Rukh Khan
#
#   country         date_added  release_year rating duration  \
# 0  Mexico  February 11, 2021          1995  TV-14   74 min
#
#             listed_in                                        description
# 0  Action & Adventure  When an unexpected event turns their life upsi...

# %%
df.iloc[:,[2,1,5]]
# Out:
#                        title     type         country
# 0           The Silent Storm    Movie          Mexico
# 1       The Forgotten Empire    Movie         Germany
# 2         The Secret Whisper    Movie          France
# 3          The Wild Symphony    Movie           Italy
# 4           The Secret Storm    Movie  United Kingdom
# ..                       ...      ...             ...
# 545         The Silent Dream    Movie          Canada
# 546   The Forgotten Protocol    Movie          Mexico
# 547  The Infinite Chronicles    Movie   United States
# 548         The Rising Truth    Movie   United States
# 549         The Velvet Truth  TV Show   United States
#
# [550 rows x 3 columns]

# %% [markdown]
# #### Q19. Select the first 10 rows using `.iloc`.

# %%
df.iloc[:10]
# Out:
#   show_id     type                 title            director  \
# 0      s1    Movie      The Silent Storm  Guillermo del Toro
# 1      s2    Movie  The Forgotten Empire       Takashi Miike
# 2      s3    Movie    The Secret Whisper   Quentin Tarantino
# 3      s4    Movie     The Wild Symphony       David Fincher
# 4      s5    Movie      The Secret Storm                 NaN
# 5      s6    Movie       The Dark Legacy    Steven Spielberg
# 6      s7    Movie     The Sacred Mirage           Spike Lee
# 7      s8    Movie    The Frozen Kingdom           Spike Lee
# 8      s9  TV Show   The Endless Kingdom      Anurag Kashyap
# 9     s10  TV Show   The Silent Symphony                 NaN
#
#                                                 cast         country  \
# 0                                     Shah Rukh Khan          Mexico
# 1                                     Lupita Nyong'o         Germany
# 2                                                NaN          France
# 3  Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                                NaN  United Kingdom
# 5                       Song Kang-ho, Mahershala Ali       Australia
# 6  Gong Yoo, Daniel Kaluuya, Song Kang-ho, Margot...  United Kingdom
# 7  Leonardo DiCaprio, Dev Patel, Pedro Pascal, Vi...         Germany
# 8                                                NaN           Japan
# 9                                                NaN          France
#
#            date_added  release_year rating   duration  \
# 0   February 11, 2021          1995  TV-14     74 min
# 1    January 14, 2020          2007  PG-13    167 min
# 2    October 08, 2021          2006  PG-13    163 min
# 3   November 23, 2015          2004      R    118 min
# 4  September 29, 2017          2000  TV-PG    118 min
# 5       July 12, 2018          2003  TV-PG    120 min
# 6    January 08, 2016          1993      R     89 min
# 7     August 15, 2023          2011      R    107 min
# 8  September 10, 2020          2002  TV-14  3 Seasons
# 9      April 29, 2024          2009  TV-14   1 Season
#
#                                            listed_in  \
# 0                                 Action & Adventure
# 1                             International TV Shows
# 2                   Romantic TV Shows, Documentaries
# 3                          Anime Series, TV Comedies
# 4                   Romantic TV Shows, Horror Movies
# 5  Anime Series, International Movies, Sci-Fi & F...
# 6  Thrillers, International TV Shows, Action & Ad...
# 7                            Thrillers, Anime Series
# 8                                  Romantic TV Shows
# 9                              TV Action & Adventure
#
#                                          description
# 0  When an unexpected event turns their life upsi...
# 1  An in-depth exploration of human emotions, sec...
# 2  In a race against time, a dedicated team unrav...
# 3  When an unexpected event turns their life upsi...
# 4  Dark forces emerge as secrets long buried fina...
# 5  When an unexpected event turns their life upsi...
# 6  In a race against time, a dedicated team unrav...
# 7  A compelling narrative following characters as...
# 8  A humorous and insightful look into modern rel...
# 9  A compelling narrative following characters as...

# %% [markdown]
# #### Q20. Select rows with labels 10 to 20 using `.loc`. How many rows do you get and why?

# %%
df.loc[10:20] # i got 11 rows cause it include form rebel 10 too.
# Out:
#    show_id   type                title            director  \
# 10     s11  Movie   The Rising Journey       Takashi Miike
# 11     s12  Movie   The Frozen Kingdom     Pedro Almodóvar
# 12     s13  Movie     The Dark Whisper     Martin Scorsese
# 13     s14  Movie    The Velvet Valley      Alfonso Cuarón
# 14     s15  Movie   The Velvet Horizon           Spike Lee
# 15     s16  Movie     The Secret Dream    Steven Spielberg
# 16     s17  Movie    The Dark Frontier       Takashi Miike
# 17     s18  Movie     The Broken Dream   Quentin Tarantino
# 18     s19  Movie     The Hidden Truth     Pedro Almodóvar
# 19     s20  Movie  The Crimson Journey  Guillermo del Toro
# 20     s21  Movie      The Lost Mirage        Greta Gerwig
#
#                                                  cast         country  \
# 10                                     Shah Rukh Khan         Germany
# 11                                                NaN           India
# 12  Scarlett Johansson, Mahershala Ali, Dev Patel,...  United Kingdom
# 13          Penélope Cruz, Pedro Pascal, Meryl Streep          Mexico
# 14  Scarlett Johansson, Denzel Washington, Penélop...         Germany
# 15                                       Song Kang-ho             NaN
# 16                                                NaN   United States
# 17  Scarlett Johansson, Daniel Kaluuya, Cillian Mu...     South Korea
# 18                         Zendaya, Denzel Washington             NaN
# 19                     Florence Pugh, Priyanka Chopra         Germany
# 20                      Florence Pugh, Cillian Murphy          France
#
#            date_added  release_year rating duration  \
# 10  December 01, 2020          2017      G  139 min
# 11    August 06, 2021          2004      G   70 min
# 12  November 23, 2024          2020      G  170 min
# 13      July 08, 2019          2011      R  101 min
# 14     April 25, 2022          2024  PG-13   81 min
# 15   October 17, 2023          2019  NC-17  124 min
# 16       May 06, 2020          2022     PG   77 min
# 17       May 04, 2021          2023  TV-MA  103 min
# 18     April 25, 2021          1996      R  138 min
# 19  November 10, 2021          2023  PG-13  155 min
# 20  February 10, 2022          2006  TV-PG  102 min
#
#                                             listed_in  \
# 10  Romantic Movies, Children & Family Movies, Cri...
# 11                                           Comedies
# 12            International TV Shows, Romantic Movies
# 13                                    Romantic Movies
# 14                                          Thrillers
# 15  Romantic TV Shows, Docuseries, International M...
# 16  Action & Adventure, Thrillers, TV Action & Adv...
# 17                                          TV Dramas
# 18                                         Reality TV
# 19  Children & Family Movies, Documentaries, Inter...
# 20                                 Action & Adventure
#
#                                           description
# 10  Dark forces emerge as secrets long buried fina...
# 11  When an unexpected event turns their life upsi...
# 12  A compelling narrative following characters as...
# 13  A heartwarming story of friendship, love, and ...
# 14  In a race against time, a dedicated team unrav...
# 15  When an unexpected event turns their life upsi...
# 16  A heartwarming story of friendship, love, and ...
# 17  When an unexpected event turns their life upsi...
# 18  An in-depth exploration of human emotions, sec...
# 19  An in-depth exploration of human emotions, sec...
# 20  Dark forces emerge as secrets long buried fina...

# %% [markdown]
# ###I got 11 rows because while selecting using loc, it includes all lebels where lebel 10 it also selected upto level 20.

# %% [markdown]
# #### Q21. Using `.iloc`, select rows at positions 5 to 14 (10 rows). Compare with Q20 — why is the row count logic different?

# %%
df.iloc[5:14,]
# Out:
#    show_id     type                title          director  \
# 5       s6    Movie      The Dark Legacy  Steven Spielberg
# 6       s7    Movie    The Sacred Mirage         Spike Lee
# 7       s8    Movie   The Frozen Kingdom         Spike Lee
# 8       s9  TV Show  The Endless Kingdom    Anurag Kashyap
# 9      s10  TV Show  The Silent Symphony               NaN
# 10     s11    Movie   The Rising Journey     Takashi Miike
# 11     s12    Movie   The Frozen Kingdom   Pedro Almodóvar
# 12     s13    Movie     The Dark Whisper   Martin Scorsese
# 13     s14    Movie    The Velvet Valley    Alfonso Cuarón
#
#                                                  cast         country  \
# 5                        Song Kang-ho, Mahershala Ali       Australia
# 6   Gong Yoo, Daniel Kaluuya, Song Kang-ho, Margot...  United Kingdom
# 7   Leonardo DiCaprio, Dev Patel, Pedro Pascal, Vi...         Germany
# 8                                                 NaN           Japan
# 9                                                 NaN          France
# 10                                     Shah Rukh Khan         Germany
# 11                                                NaN           India
# 12  Scarlett Johansson, Mahershala Ali, Dev Patel,...  United Kingdom
# 13          Penélope Cruz, Pedro Pascal, Meryl Streep          Mexico
#
#             date_added  release_year rating   duration  \
# 5        July 12, 2018          2003  TV-PG    120 min
# 6     January 08, 2016          1993      R     89 min
# 7      August 15, 2023          2011      R    107 min
# 8   September 10, 2020          2002  TV-14  3 Seasons
# 9       April 29, 2024          2009  TV-14   1 Season
# 10   December 01, 2020          2017      G    139 min
# 11     August 06, 2021          2004      G     70 min
# 12   November 23, 2024          2020      G    170 min
# 13       July 08, 2019          2011      R    101 min
#
#                                             listed_in  \
# 5   Anime Series, International Movies, Sci-Fi & F...
# 6   Thrillers, International TV Shows, Action & Ad...
# 7                             Thrillers, Anime Series
# 8                                   Romantic TV Shows
# 9                               TV Action & Adventure
# 10  Romantic Movies, Children & Family Movies, Cri...
# 11                                           Comedies
# 12            International TV Shows, Romantic Movies
# 13                                    Romantic Movies
#
#                                           description
# 5   When an unexpected event turns their life upsi...
# 6   In a race against time, a dedicated team unrav...
# 7   A compelling narrative following characters as...
# 8   A humorous and insightful look into modern rel...
# 9   A compelling narrative following characters as...
# 10  Dark forces emerge as secrets long buried fina...
# 11  When an unexpected event turns their life upsi...
# 12  A compelling narrative following characters as...
# 13  A heartwarming story of friendship, love, and ...

# %% [markdown]
# ### The logic is different because while using iloc the selection start using index and index starts form 0.

# %% [markdown]
# #### Q22. Using `.loc`, select rows 0 to 9 with only the columns `title` and `release_year`.

# %%
df.loc[0:9,["title","release_year"]]
# Out:
#                   title  release_year
# 0      The Silent Storm          1995
# 1  The Forgotten Empire          2007
# 2    The Secret Whisper          2006
# 3     The Wild Symphony          2004
# 4      The Secret Storm          2000
# 5       The Dark Legacy          2003
# 6     The Sacred Mirage          1993
# 7    The Frozen Kingdom          2011
# 8   The Endless Kingdom          2002
# 9   The Silent Symphony          2009

# %% [markdown]
# #### Q23. Using `.iloc`, select the first 8 rows and the first 5 columns.

# %%
df.iloc[0:8,0:5]
# Out:
#   show_id   type                 title            director  \
# 0      s1  Movie      The Silent Storm  Guillermo del Toro
# 1      s2  Movie  The Forgotten Empire       Takashi Miike
# 2      s3  Movie    The Secret Whisper   Quentin Tarantino
# 3      s4  Movie     The Wild Symphony       David Fincher
# 4      s5  Movie      The Secret Storm                 NaN
# 5      s6  Movie       The Dark Legacy    Steven Spielberg
# 6      s7  Movie     The Sacred Mirage           Spike Lee
# 7      s8  Movie    The Frozen Kingdom           Spike Lee
#
#                                                 cast
# 0                                     Shah Rukh Khan
# 1                                     Lupita Nyong'o
# 2                                                NaN
# 3  Tom Hanks, Lupita Nyong'o, Denzel Washington, ...
# 4                                                NaN
# 5                       Song Kang-ho, Mahershala Ali
# 6  Gong Yoo, Daniel Kaluuya, Song Kang-ho, Margot...
# 7  Leonardo DiCaprio, Dev Patel, Pedro Pascal, Vi...

# %% [markdown]
# #### Q24. Using `.iloc`, select the **last row** of the DataFrame.

# %%
df.iloc[-1]
# Out:
# show_id                                                      s550
# type                                                      TV Show
# title                                            The Velvet Truth
# director                                       Guillermo del Toro
# cast                        Timothée Chalamet, Scarlett Johansson
# country                                             United States
# date_added                                          June 16, 2022
# release_year                                                 2005
# rating                                                       TV-G
# duration                                                6 Seasons
# listed_in               Horror Movies, Crime TV Shows, Reality TV
# description     An in-depth exploration of human emotions, sec...
# Name: 549, dtype: object

# %% [markdown]
# #### Q25. Using `.iloc`, select the last 5 rows and the last 2 columns (negative positions).

# %%
df.iloc[-5:,-2:]
# Out:
#                                              listed_in  \
# 545                                    Romantic Movies
# 546          TV Dramas, Docuseries, Action & Adventure
# 547  International TV Shows, Horror Movies, Action ...
# 548                                TV Dramas, Comedies
# 549          Horror Movies, Crime TV Shows, Reality TV
#
#                                            description
# 545  In a race against time, a dedicated team unrav...
# 546  An in-depth exploration of human emotions, sec...
# 547  A compelling narrative following characters as...
# 548  A heartwarming story of friendship, love, and ...
# 549  An in-depth exploration of human emotions, sec...

# %% [markdown]
# #### Q26. Using `.loc`, get the value of `title` for the row with label 50.

# %%
df.loc[50,"title"]
# Out:
# 'The Rising Chronicles'

# %%
#let find out the value of "type" of row level 30

df.loc[30,"type"]
# Out:
# 'TV Show'

# %% [markdown]
# #### Q27. Using `.iloc`, get the value in row position 100, column position 2. Which column is that?

# %%
df.iloc[100,2]
# Out:
# 'The Fallen Dream'

# %%
# value of 200 in positiono 3
df.iloc[200,3]
# Out:
# 'Taika Waititi'

# %% [markdown]
# #### Q28. Using `.iloc`, select every 100th row (hint: slicing with a step `::100`).

# %%
# Your answer here
df.iloc[::100]
# Out:
#     show_id     type                   title            director  \
# 0        s1    Movie        The Silent Storm  Guillermo del Toro
# 100    s101  TV Show        The Fallen Dream       Takashi Miike
# 200    s201    Movie         The Hidden Echo       Taika Waititi
# 300    s301    Movie      The Eternal Empire        Greta Gerwig
# 400    s401  TV Show      The Broken Whisper                 NaN
# 500    s501    Movie  The Forgotten Frontier  Guillermo del Toro
#
#                                                   cast    country  \
# 0                                       Shah Rukh Khan     Mexico
# 100              Mahershala Ali, Meryl Streep, Zendaya      Japan
# 200  Cillian Murphy, Scarlett Johansson, Ana de Arm...    Germany
# 300                                          Dev Patel     Brazil
# 400                                     Daniel Kaluuya  Australia
# 500            Marion Cotillard, Zendaya, Song Kang-ho      Japan
#
#              date_added  release_year rating   duration  \
# 0     February 11, 2021          1995  TV-14     74 min
# 100    October 04, 2023          1993   TV-G  3 Seasons
# 200   December 26, 2015          2007  TV-14     87 min
# 300   November 24, 2015          2003     PG    120 min
# 400  September 08, 2019          1992  TV-MA  4 Seasons
# 500      March 18, 2020          2016      R    131 min
#
#                                         listed_in  \
# 0                              Action & Adventure
# 100                    Documentaries, TV Comedies
# 200                   Romantic Movies, Reality TV
# 300                                 Documentaries
# 400  Reality TV, Comedies, International TV Shows
# 500                        International TV Shows
#
#                                            description
# 0    When an unexpected event turns their life upsi...
# 100  In a race against time, a dedicated team unrav...
# 200  When an unexpected event turns their life upsi...
# 300  A compelling narrative following characters as...
# 400  A heartwarming story of friendship, love, and ...
# 500  Dark forces emerge as secrets long buried fina...

# %% [markdown]
# #### Q29. Using `.loc`, select rows 0 to 4 and **all** columns from `title` to `country` (label slicing on columns!).

# %%
# Your answer here
df.loc[0:4,"title":"country"]
# Out:
#                   title            director  \
# 0      The Silent Storm  Guillermo del Toro
# 1  The Forgotten Empire       Takashi Miike
# 2    The Secret Whisper   Quentin Tarantino
# 3     The Wild Symphony       David Fincher
# 4      The Secret Storm                 NaN
#
#                                                 cast         country
# 0                                     Shah Rukh Khan          Mexico
# 1                                     Lupita Nyong'o         Germany
# 2                                                NaN          France
# 3  Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                                NaN  United Kingdom

# %% [markdown]
# #### Q30. Select three specific rows by label — 3, 33, and 333 — in one `.loc` call.

# %%
df.loc[[3,33,333]]
# Out:
#     show_id   type              title         director  \
# 3        s4  Movie  The Wild Symphony    David Fincher
# 33      s34  Movie   The Hidden Heart  Martin Scorsese
# 333    s334  Movie  The Frozen Mirage              NaN
#
#                                                   cast        country  \
# 3    Tom Hanks, Lupita Nyong'o, Denzel Washington, ...          Italy
# 33                Gong Yoo, Timothée Chalamet, Omar Sy  United States
# 333                                                NaN            NaN
#
#              date_added  release_year rating duration  \
# 3     November 23, 2015          2004      R  118 min
# 33   September 17, 2019          2014  PG-13  179 min
# 333       June 02, 2018          2011  TV-PG  120 min
#
#                               listed_in  \
# 3             Anime Series, TV Comedies
# 33   Crime TV Shows, Docuseries, Dramas
# 333      Thrillers, Dramas, TV Comedies
#
#                                            description
# 3    When an unexpected event turns their life upsi...
# 33   An in-depth exploration of human emotions, sec...
# 333  Dark forces emerge as secrets long buried fina...

# %% [markdown]
# #### Q31. Set `show_id` as the index of `df` (keep it for the rest of Section B). Display the head.

# %%
df
# Out:
#     show_id     type                    title            director  \
# 0        s1    Movie         The Silent Storm  Guillermo del Toro
# 1        s2    Movie     The Forgotten Empire       Takashi Miike
# 2        s3    Movie       The Secret Whisper   Quentin Tarantino
# 3        s4    Movie        The Wild Symphony       David Fincher
# 4        s5    Movie         The Secret Storm                 NaN
# ..      ...      ...                      ...                 ...
# 545    s546    Movie         The Silent Dream                 NaN
# 546    s547    Movie   The Forgotten Protocol   Quentin Tarantino
# 547    s548    Movie  The Infinite Chronicles       James Cameron
# 548    s549    Movie         The Rising Truth        Bong Joon-ho
# 549    s550  TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                   cast         country  \
# 0                                       Shah Rukh Khan          Mexico
# 1                                       Lupita Nyong'o         Germany
# 2                                                  NaN          France
# 3    Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                                  NaN  United Kingdom
# ..                                                 ...             ...
# 545                    Leonardo DiCaprio, Song Kang-ho          Canada
# 546  Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# 547  Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# 548                                       Song Kang-ho   United States
# 549              Timothée Chalamet, Scarlett Johansson   United States
#
#              date_added  release_year rating   duration  \
# 0     February 11, 2021          1995  TV-14     74 min
# 1      January 14, 2020          2007  PG-13    167 min
# 2      October 08, 2021          2006  PG-13    163 min
# 3     November 23, 2015          2004      R    118 min
# 4    September 29, 2017          2000  TV-PG    118 min
# ..                  ...           ...    ...        ...
# 545   February 21, 2024          2007  TV-MA     75 min
# 546     August 08, 2022          1998  TV-MA     92 min
# 547   November 29, 2021          1997  NC-17    100 min
# 548   February 18, 2023          2018  TV-MA     87 min
# 549       June 16, 2022          2005   TV-G  6 Seasons
#
#                                              listed_in  \
# 0                                   Action & Adventure
# 1                               International TV Shows
# 2                     Romantic TV Shows, Documentaries
# 3                            Anime Series, TV Comedies
# 4                     Romantic TV Shows, Horror Movies
# ..                                                 ...
# 545                                    Romantic Movies
# 546          TV Dramas, Docuseries, Action & Adventure
# 547  International TV Shows, Horror Movies, Action ...
# 548                                TV Dramas, Comedies
# 549          Horror Movies, Crime TV Shows, Reality TV
#
#                                            description
# 0    When an unexpected event turns their life upsi...
# 1    An in-depth exploration of human emotions, sec...
# 2    In a race against time, a dedicated team unrav...
# 3    When an unexpected event turns their life upsi...
# 4    Dark forces emerge as secrets long buried fina...
# ..                                                 ...
# 545  In a race against time, a dedicated team unrav...
# 546  An in-depth exploration of human emotions, sec...
# 547  A compelling narrative following characters as...
# 548  A heartwarming story of friendship, love, and ...
# 549  An in-depth exploration of human emotions, sec...
#
# [550 rows x 12 columns]

# %%
if df.index.name == "show_id":
  df.reset_index(inplace=True)

df.set_index("show_id",inplace=True)
df.head()
# Out:
#           type                 title            director  \
# show_id
# s1       Movie      The Silent Storm  Guillermo del Toro
# s2       Movie  The Forgotten Empire       Takashi Miike
# s3       Movie    The Secret Whisper   Quentin Tarantino
# s4       Movie     The Wild Symphony       David Fincher
# s5       Movie      The Secret Storm                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
#
#                  date_added  release_year rating duration  \
# show_id
# s1        February 11, 2021          1995  TV-14   74 min
# s2         January 14, 2020          2007  PG-13  167 min
# s3         October 08, 2021          2006  PG-13  163 min
# s4        November 23, 2015          2004      R  118 min
# s5       September 29, 2017          2000  TV-PG  118 min
#
#                                 listed_in  \
# show_id
# s1                     Action & Adventure
# s2                 International TV Shows
# s3       Romantic TV Shows, Documentaries
# s4              Anime Series, TV Comedies
# s5       Romantic TV Shows, Horror Movies
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...
# s2       An in-depth exploration of human emotions, sec...
# s3       In a race against time, a dedicated team unrav...
# s4       When an unexpected event turns their life upsi...
# s5       Dark forces emerge as secrets long buried fina...

# %% [markdown]
# #### Q32. Using `.loc`, select the row with label `"s1"`.

# %%
df.loc["s1"]
# Out:
# type                                                        Movie
# title                                            The Silent Storm
# director                                       Guillermo del Toro
# cast                                               Shah Rukh Khan
# country                                                    Mexico
# date_added                                      February 11, 2021
# release_year                                                 1995
# rating                                                      TV-14
# duration                                                   74 min
# listed_in                                      Action & Adventure
# description     When an unexpected event turns their life upsi...
# Name: s1, dtype: object

# %% [markdown]
# #### Q33. Using `.loc`, select rows `"s10"` to `"s15"`. Does label slicing still include the end?

# %%
df.loc["s10":"s15"]
# Out:
#             type                title         director  \
# show_id
# s10      TV Show  The Silent Symphony              NaN
# s11        Movie   The Rising Journey    Takashi Miike
# s12        Movie   The Frozen Kingdom  Pedro Almodóvar
# s13        Movie     The Dark Whisper  Martin Scorsese
# s14        Movie    The Velvet Valley   Alfonso Cuarón
# s15        Movie   The Velvet Horizon        Spike Lee
#
#                                                       cast         country  \
# show_id
# s10                                                    NaN          France
# s11                                         Shah Rukh Khan         Germany
# s12                                                    NaN           India
# s13      Scarlett Johansson, Mahershala Ali, Dev Patel,...  United Kingdom
# s14              Penélope Cruz, Pedro Pascal, Meryl Streep          Mexico
# s15      Scarlett Johansson, Denzel Washington, Penélop...         Germany
#
#                 date_added  release_year rating  duration  \
# show_id
# s10         April 29, 2024          2009  TV-14  1 Season
# s11      December 01, 2020          2017      G   139 min
# s12        August 06, 2021          2004      G    70 min
# s13      November 23, 2024          2020      G   170 min
# s14          July 08, 2019          2011      R   101 min
# s15         April 25, 2022          2024  PG-13    81 min
#
#                                                  listed_in  \
# show_id
# s10                                  TV Action & Adventure
# s11      Romantic Movies, Children & Family Movies, Cri...
# s12                                               Comedies
# s13                International TV Shows, Romantic Movies
# s14                                        Romantic Movies
# s15                                              Thrillers
#
#                                                description
# show_id
# s10      A compelling narrative following characters as...
# s11      Dark forces emerge as secrets long buried fina...
# s12      When an unexpected event turns their life upsi...
# s13      A compelling narrative following characters as...
# s14      A heartwarming story of friendship, love, and ...
# s15      In a race against time, a dedicated team unrav...

# %% [markdown]
# #### Q34. Using `.iloc`, select the row at position 0. Is it the same row as label `"s1"`?

# %%
df.iloc[0] # Yes it is the same row as lebel 's1'.
# Out:
# type                                                        Movie
# title                                            The Silent Storm
# director                                       Guillermo del Toro
# cast                                               Shah Rukh Khan
# country                                                    Mexico
# date_added                                      February 11, 2021
# release_year                                                 1995
# rating                                                      TV-14
# duration                                                   74 min
# listed_in                                      Action & Adventure
# description     When an unexpected event turns their life upsi...
# Name: s1, dtype: object

# %% [markdown]
# #### Q35. Using `.loc`, get the `title` and `type` of the show with id `"s500"`.

# %%
df.loc["s500",["title","type"]]
# Out:
# title    The Eternal Echo
# type              TV Show
# Name: s500, dtype: object

# %% [markdown]
# #### Q36. Using `.iloc`, select the row at position 499. Is its label `"s500"`? Explain why or why not in a comment.

# %%
df.iloc[499]
# Out:
# type                                                      TV Show
# title                                            The Eternal Echo
# director                                             Ava DuVernay
# cast                                            Leonardo DiCaprio
# country                                                     Japan
# date_added                                        August 03, 2018
# release_year                                                 1999
# rating                                                      TV-Y7
# duration                                                3 Seasons
# listed_in                           Crime TV Shows, Documentaries
# description     A compelling narrative following characters as...
# Name: s500, dtype: object

# %% [markdown]
# ### Yes, it is lebel s500 cause in 'iloc' index start form 0.

# %% [markdown]
# #### Q37. Using `.loc`, select shows `"s1"`, `"s100"`, and `"s500"` with columns `title` and `release_year`.

# %%
df.loc[["s1","s100","s500"],["title","release_year"]]
# Out:
#                           title  release_year
# show_id
# s1             The Silent Storm          1995
# s100     The Eternal Chronicles          2008
# s500           The Eternal Echo          1999

# %% [markdown]
# #### Q38. What happens if you run `df.loc[0]` now? Try it, read the error, and explain in a comment.

# %%
df.loc[0]

# %% [markdown]
# ###loc read lebel not the index

# %% [markdown]
# #### Q39. Using `.iloc`, select rows at positions [0, 99, 499] in one call.

# %%
df.iloc[[0,99,499]]
# Out:
#             type             title            director  \
# show_id
# s1         Movie  The Silent Storm  Guillermo del Toro
# s101     TV Show  The Fallen Dream       Takashi Miike
# s509     TV Show    The Dark Storm             Unknown
#
#                                                       cast country  \
# show_id
# s1                                          Shah Rukh Khan  Mexico
# s101                 Mahershala Ali, Meryl Streep, Zendaya   Japan
# s509     Tom Hanks, Leonardo DiCaprio, Ana de Armas, So...   Japan
#
#                 date_added  release_year rating   duration  \
# show_id
# s1       February 11, 2021          1995  TV-14     74 min
# s101      October 04, 2023          1993   TV-G  3 Seasons
# s509         July 16, 2020          2000   TV-Y  2 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s101                            Documentaries, TV Comedies
# s509     TV Action & Adventure, Thrillers, Action & Adv...
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       32.0
# s101     In a race against time, a dedicated team unrav...       34.0
# s509     A heartwarming story of friendship, love, and ...       27.0
#
#         is_movie is_recent  title_length platform  era
# show_id
# s1          True     False          16.0  Netflix  old
# s101       False     False          16.0  Netflix  old
# s509       False     False          14.0  Netflix  old

# %% [markdown]
# #### Q40. Reset the index back to 0,1,2,... using `reset_index()`. Display the head.

# %%
# Drop extra index columns created by previous reset_index calls if they exist
df = df.drop(columns=['level_0', 'index'], errors='ignore')

# If show_id is currently a column, make it the index first so reset_index puts it back correctly
if 'show_id' in df.columns:
    df.set_index('show_id', inplace=True)

df.reset_index(inplace=True)
df.head()
# Out:
#   show_id   type                 title            director  \
# 0      s1  Movie      The Silent Storm  Guillermo del Toro
# 1      s2  Movie  The Forgotten Empire       Takashi Miike
# 2      s3  Movie    The Secret Whisper   Quentin Tarantino
# 3      s4  Movie     The Wild Symphony       David Fincher
# 4      s5  Movie      The Secret Storm             Unknown
#
#                                                 cast         country  \
# 0                                     Shah Rukh Khan          Mexico
# 1                                     Lupita Nyong'o         Germany
# 2                                            Unknown          France
# 3  Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                            Unknown  United Kingdom
#
#            date_added  release_year rating duration  \
# 0   February 11, 2021          1995  TV-14   74 min
# 1    January 14, 2020          2007  PG-13  167 min
# 2    October 08, 2021          2006  PG-13  163 min
# 3   November 23, 2015          2004      R  118 min
# 4  September 29, 2017          2000  TV-PG  118 min
#
#                              genres  \
# 0                Action & Adventure
# 1            International TV Shows
# 2  Romantic TV Shows, Documentaries
# 3         Anime Series, TV Comedies
# 4  Romantic TV Shows, Horror Movies
#
#                                          description  age_years is_movie  \
# 0  When an unexpected event turns their life upsi...       32.0     True
# 1  An in-depth exploration of human emotions, sec...       20.0     True
# 2  In a race against time, a dedicated team unrav...       21.0     True
# 3  When an unexpected event turns their life upsi...       23.0     True
# 4  Dark forces emerge as secrets long buried fina...       27.0     True
#
#   is_recent  title_length platform  era
# 0     False          16.0  Netflix  old
# 1     False          20.0  Netflix  old
# 2     False          18.0  Netflix  old
# 3     False          17.0  Netflix  old
# 4     False          16.0  Netflix  old

# %% [markdown]
# ## Section C — Conditions with `.loc` (Q41–Q60)
# *Write every filter with `df.loc[condition]` or `df.loc[condition, columns]` style where possible.*

# %% [markdown]
# #### Q41. Select all rows where `type` is `"Movie"`.

# %%
df.loc[df.type == "Movie"]
# Out:
#     show_id   type                    title            director  \
# 0        s1  Movie         The Silent Storm  Guillermo del Toro
# 1        s2  Movie     The Forgotten Empire       Takashi Miike
# 2        s3  Movie       The Secret Whisper   Quentin Tarantino
# 3        s4  Movie        The Wild Symphony       David Fincher
# 4        s5  Movie         The Secret Storm             Unknown
# ..      ...    ...                      ...                 ...
# 533    s544  Movie       The Midnight Heart  Guillermo del Toro
# 535    s546  Movie         The Silent Dream             Unknown
# 536    s547  Movie   The Forgotten Protocol   Quentin Tarantino
# 537    s548  Movie  The Infinite Chronicles       James Cameron
# 538    s549  Movie         The Rising Truth        Bong Joon-ho
#
#                                                   cast         country  \
# 0                                       Shah Rukh Khan          Mexico
# 1                                       Lupita Nyong'o         Germany
# 2                                              Unknown          France
# 3    Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# 4                                              Unknown  United Kingdom
# ..                                                 ...             ...
# 533                      Scarlett Johansson, Tom Hanks     South Korea
# 535                    Leonardo DiCaprio, Song Kang-ho          Canada
# 536  Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# 537  Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# 538                                       Song Kang-ho             USA
#
#              date_added  release_year rating duration  \
# 0     February 11, 2021          1995  TV-14   74 min
# 1      January 14, 2020          2007  PG-13  167 min
# 2      October 08, 2021          2006  PG-13  163 min
# 3     November 23, 2015          2004      R  118 min
# 4    September 29, 2017          2000  TV-PG  118 min
# ..                  ...           ...    ...      ...
# 533      March 01, 2015          2011      G  157 min
# 535   February 21, 2024          2007  TV-MA   75 min
# 536     August 08, 2022          1998  TV-MA   92 min
# 537   November 29, 2021          1997  NC-17  100 min
# 538   February 18, 2023          2018  TV-MA   87 min
#
#                                                 genres  \
# 0                                   Action & Adventure
# 1                               International TV Shows
# 2                     Romantic TV Shows, Documentaries
# 3                            Anime Series, TV Comedies
# 4                     Romantic TV Shows, Horror Movies
# ..                                                 ...
# 533   Action & Adventure, Horror Movies, Documentaries
# 535                                    Romantic Movies
# 536          TV Dramas, Docuseries, Action & Adventure
# 537  International TV Shows, Horror Movies, Action ...
# 538                                TV Dramas, Comedies
#
#                                            description  age_years is_movie  \
# 0    When an unexpected event turns their life upsi...       32.0     True
# 1    An in-depth exploration of human emotions, sec...       20.0     True
# 2    In a race against time, a dedicated team unrav...       21.0     True
# 3    When an unexpected event turns their life upsi...       23.0     True
# 4    Dark forces emerge as secrets long buried fina...       27.0     True
# ..                                                 ...        ...      ...
# 533  A humorous and insightful look into modern rel...       16.0     True
# 535  In a race against time, a dedicated team unrav...       20.0     True
# 536  An in-depth exploration of human emotions, sec...       29.0     True
# 537  A compelling narrative following characters as...       30.0     True
# 538  A heartwarming story of friendship, love, and ...        9.0     True
#
#     is_recent  title_length platform  era
# 0       False          16.0  Netflix  old
# 1       False          20.0  Netflix  old
# 2       False          18.0  Netflix  old
# 3       False          17.0  Netflix  old
# 4       False          16.0  Netflix  old
# ..        ...           ...      ...  ...
# 533     False          18.0  Netflix  new
# 535     False          16.0  Netflix  old
# 536     False          22.0  Netflix  old
# 537     False          23.0  Netflix  old
# 538     False          16.0  Netflix  new
#
# [389 rows x 18 columns]

# %% [markdown]
# #### Q42. Select all rows where `type` is `"TV Show"` — show only `title` and `country` using one `.loc` call.

# %%
df.loc[df.type == "TV Show",["title","country"]]

# %% [markdown]
# #### Q43. Select all titles released in 2021.

# %%
df.loc[df.release_year == 2021,["title","release_year"]]

# %% [markdown]
# #### Q44. Select all titles released **before** 2000.

# %%
df.loc[df.release_year < 2000, ['title','release_year']]

# %% [markdown]
# #### Q45. Select all titles released between 2015 and 2020 (inclusive) — two conditions with `&`.

# %%
df.loc[(df.release_year > 2015)& (df.release_year <2020),["title","release_year"]]
# Out:
#                        title  release_year
# show_id
# s11       The Rising Journey          2017
# s16         The Secret Dream          2019
# s22         The Endless Echo          2017
# s26         The Fallen Dream          2017
# s29         The Silent Truth          2018
# ...                      ...           ...
# s532      The Shadow Journey          2018
# s534     The Shadow Frontier          2018
# s540     The Secret Protocol          2018
# s545     The Eternal Horizon          2017
# s549        The Rising Truth          2018
#
# [77 rows x 2 columns]

# %% [markdown]
# #### Q46. Select all Movies released after 2019 (two conditions).

# %%
df.loc[(df.type == "Movie") & (df.release_year > 2019),["title","release_year"]]
# Out:
#                           title  release_year
# show_id
# s13            The Dark Whisper          2020
# s15          The Velvet Horizon          2024
# s17           The Dark Frontier          2022
# s18            The Broken Dream          2023
# s20         The Crimson Journey          2023
# s27          The Infinite Heart          2024
# s40           The Sacred Shadow          2021
# s54      The Forgotten Protocol          2021
# s55          The Velvet Journey          2021
# s93       The Broken Chronicles          2020
# s95          The Frozen Kingdom          2022
# s96            The Lost Whisper          2020
# s111           The Fallen Truth          2024
# s116       The Midnight Kingdom          2020
# s122        The Fallen Symphony          2020
# s125           The Sacred Storm          2023
# s126         The Rising Promise          2020
# s135          The Velvet Valley          2020
# s145           The Broken Dream          2021
# s150          The Rising Shadow          2020
# s189        The Crimson Horizon          2022
# s192          The Silent Valley          2021
# s196       The Infinite Promise          2024
# s206            The Shadow Echo          2023
# s225       The Eternal Frontier          2022
# s233       The Eternal Frontier          2020
# s239        The Endless Kingdom          2020
# s244      The Velvet Chronicles          2023
# s270          The Crimson Truth          2024
# s271        The Silent Frontier          2020
# s277          The Velvet Empire          2022
# s282         The Broken Journey          2023
# s283          The Shadow Shadow          2024
# s286           The Golden Storm          2023
# s303         The Hidden Kingdom          2020
# s305           The Velvet Storm          2024
# s354        The Hidden Protocol          2023
# s355          The Shadow Valley          2024
# s371          The Fallen Shadow          2021
# s378          The Velvet Empire          2024
# s385          The Endless Night          2021
# s394      The Fallen Chronicles          2021
# s404       The Midnight Whisper          2024
# s406          The Lost Protocol          2022
# s408       The Midnight Horizon          2021
# s423         The Hidden Kingdom          2022
# s437           The Wild Horizon          2021
# s441         The Secret Whisper          2021
# s442         The Infinite Dream          2023
# s460             The Wild Dream          2022
# s469           The Dark Kingdom          2023
# s478     The Crimson Chronicles          2022
# s486             The Dark Night          2023
# s490      The Silent Chronicles          2024
# s497        The Silent Frontier          2024
# s498         The Sacred Horizon          2024
# s504        The Midnight Valley          2024
# s510           The Golden Night          2024
# s530          The Endless Truth          2024

# %% [markdown]
# #### Q47. Select all titles where `rating` is `"TV-MA"`.

# %%
df.loc[df.rating == "TV-MA", ["title","rating"]]
# Out:
#                           title rating
# show_id
# s18            The Broken Dream  TV-MA
# s23        The Crimson Frontier  TV-MA
# s26            The Fallen Dream  TV-MA
# s30         The Eternal Journey  TV-MA
# s33            The Broken Storm  TV-MA
# ...                         ...    ...
# s517         The Crimson Shadow  TV-MA
# s545        The Eternal Horizon  TV-MA
# s546           The Silent Dream  TV-MA
# s547     The Forgotten Protocol  TV-MA
# s549           The Rising Truth  TV-MA
#
# [92 rows x 2 columns]

# %% [markdown]
# #### Q48. Select all titles where `rating` is either `"PG"` or `"PG-13"` using `.isin()`.

# %%
# Using .isin () method

df[df["rating"].isin(["PG", "PG-13"])][["title","rating"]]
# Out:
#                          title rating
# show_id
# s2        The Forgotten Empire  PG-13
# s3          The Secret Whisper  PG-13
# s15         The Velvet Horizon  PG-13
# s17          The Dark Frontier     PG
# s20        The Crimson Journey  PG-13
# ...                        ...    ...
# s518          The Shadow Truth  PG-13
# s529        The Fallen Kingdom  PG-13
# s539      The Forgotten Shadow     PG
# s541     The Golden Chronicles     PG
# s542     The Broken Chronicles     PG
#
# [87 rows x 2 columns]

# %% [markdown]
# #### Q49. Select all titles where `rating` is **NOT** `"TV-MA"` (hint: `~` or `!=`).

# %%
df.loc[df.rating != "TV-MA",["title","rating"]]
# Out:
#                            title rating
# show_id
# s1              The Silent Storm  TV-14
# s2          The Forgotten Empire  PG-13
# s3            The Secret Whisper  PG-13
# s4             The Wild Symphony      R
# s5              The Secret Storm  TV-PG
# ...                          ...    ...
# s542       The Broken Chronicles     PG
# s543             The Secret Echo  TV-14
# s544          The Midnight Heart      G
# s548     The Infinite Chronicles  NC-17
# s550            The Velvet Truth   TV-G
#
# [458 rows x 2 columns]

# %% [markdown]
# #### Q50. Select all titles where `country` is exactly `"India"`.

# %%
df.loc[df.country =="India",["title","country"]]
# Out:
#                        title country
# show_id
# s12       The Frozen Kingdom   India
# s47        The Infinite Echo   India
# s55       The Velvet Journey   India
# s81        The Frozen Shadow   India
# s87           The Wild Storm   India
# s97        The Hidden Mirage   India
# s172        The Broken Truth   India
# s199        The Broken Night   India
# s209       The Golden Legacy   India
# s238        The Lost Kingdom   India
# s273     The Hidden Protocol   India
# s276        The Secret Night   India
# s290      The Broken Whisper   India
# s313       The Broken Empire   India
# s330        The Broken Heart   India
# s344       The Frozen Empire   India
# s349        The Crimson Echo   India
# s363      The Shadow Whisper   India
# s381     The Forgotten Heart   India
# s387      The Secret Horizon   India
# s397         The Dark Mirage   India
# s417        The Golden Night   India
# s424       The Fallen Mirage   India
# s430     The Midnight Shadow   India
# s436       The Sacred Mirage   India
# s452     The Rising Protocol   India
# s463      The Crimson Mirage   India
# s476       The Wild Frontier   India
# s499       The Velvet Empire   India
# s527        The Secret Truth   India

# %% [markdown]
# #### Q51. Select all titles where `country` **contains** `"India"` (hint: `str.contains`, use `na=False`). Why is the row count different from the previous question?

# %%
df["country"].str.contains('India',na=False)
# Out:
# show_id
# s1      False
# s2      False
# s3      False
# s4      False
# s5      False
#         ...
# s546    False
# s547    False
# s548    False
# s549    False
# s550    False
# Name: country, Length: 550, dtype: bool

# %% [markdown]
# ###The row count is different from the previous question because it skip all the rows which doesnot contains india.

# %% [markdown]
# #### Q52. Select all Movies from the United States — show only `title` and `release_year`.

# %%
df.loc[df.country == "United States" , ["title","release_year"]]
# Out:
#                            title  release_year
# show_id
# s17            The Dark Frontier          2022
# s27           The Infinite Heart          2024
# s31           The Infinite Heart          1996
# s34             The Hidden Heart          2014
# s35          The Midnight Shadow          2015
# s40            The Sacred Shadow          2021
# s43            The Rising Mirage          2015
# s49           The Golden Horizon          2008
# s51        The Rising Chronicles          1991
# s62          The Rising Frontier          2008
# s83           The Broken Kingdom          1994
# s95           The Frozen Kingdom          2022
# s110           The Hidden Mirage          1999
# s112       The Forgotten Whisper          2006
# s116        The Midnight Kingdom          2020
# s135           The Velvet Valley          2020
# s144          The Frozen Promise          1999
# s147           The Frozen Valley          2016
# s150           The Rising Shadow          2020
# s177             The Shadow Echo          2002
# s179            The Golden Night          2011
# s182           The Broken Mirage          2009
# s193           The Sacred Valley          2009
# s205           The Rising Mirage          2011
# s211         The Infinite Legacy          2006
# s220          The Crimson Shadow          1999
# s239         The Endless Kingdom          2020
# s260           The Crimson Truth          2018
# s340         The Crimson Horizon          2007
# s350          The Shadow Kingdom          2023
# s394       The Fallen Chronicles          2021
# s396         The Hidden Protocol          2008
# s402         The Lost Chronicles          2003
# s427              The Lost Storm          1997
# s438          The Infinite Dream          2013
# s444            The Frozen Storm          2019
# s462         The Shadow Protocol          2020
# s471          The Infinite Storm          2019
# s473           The Velvet Mirage          2019
# s477       The Midnight Protocol          2010
# s480         The Velvet Protocol          2012
# s482            The Lost Promise          1997
# s485       The Velvet Chronicles          1994
# s493       The Rising Chronicles          2013
# s514         The Golden Symphony          1994
# s517          The Crimson Shadow          2017
# s548     The Infinite Chronicles          1997
# s549            The Rising Truth          2018
# s550            The Velvet Truth          2005

# %% [markdown]
# #### Q53. Select all titles where `director` is missing (hint: `isna()`).

# %%
df[df["director"].isna()][["title","director"]]
# Out:
#                          title director
# show_id
# s5            The Secret Storm      NaN
# s10        The Silent Symphony      NaN
# s26           The Fallen Dream      NaN
# s30        The Eternal Journey      NaN
# s39         The Infinite Dream      NaN
# ...                        ...      ...
# s538     The Rising Chronicles      NaN
# s540       The Secret Protocol      NaN
# s543           The Secret Echo      NaN
# s545       The Eternal Horizon      NaN
# s546          The Silent Dream      NaN
#
# [157 rows x 2 columns]

# %% [markdown]
# #### Q54. Select all titles where `director` is **not** missing.

# %%
df[~df["director"].isna()][["title","director"]]
# Out:
#                            title            director
# show_id
# s1              The Silent Storm  Guillermo del Toro
# s2          The Forgotten Empire       Takashi Miike
# s3            The Secret Whisper   Quentin Tarantino
# s4             The Wild Symphony       David Fincher
# s6               The Dark Legacy    Steven Spielberg
# ...                          ...                 ...
# s544          The Midnight Heart  Guillermo del Toro
# s547      The Forgotten Protocol   Quentin Tarantino
# s548     The Infinite Chronicles       James Cameron
# s549            The Rising Truth        Bong Joon-ho
# s550            The Velvet Truth  Guillermo del Toro
#
# [393 rows x 2 columns]

# %% [markdown]
# #### Q55. Select all TV Shows released in 2020 **or** 2021.

# %%
# Fixed the logic: use parentheses () for grouping conditions and avoid extra brackets around the list of columns.
df.loc[(df.type == "TV Show") & ((df.release_year == 2020) | (df.release_year == 2021)), ["title", "type", "release_year"]]
# Out:
#                         title     type  release_year
# show_id
# s91        The Hidden Kingdom  TV Show          2021
# s108       The Eternal Valley  TV Show          2021
# s160         The Frozen Heart  TV Show          2021
# s213         The Sacred Storm  TV Show          2021
# s237          The Lost Empire  TV Show          2020
# s318       The Secret Promise  TV Show          2021
# s365     The Midnight Journey  TV Show          2021
# s387       The Secret Horizon  TV Show          2021
# s400         The Broken Truth  TV Show          2020
# s462      The Shadow Protocol  TV Show          2020
# s479      The Midnight Shadow  TV Show          2020

# %% [markdown]
# #### Q56. Select all titles whose `title` starts with the letter `"A"` (hint: `str.startswith`, `na=False`).

# %%
df.loc[df["title"].str.startswith("A",na=False), "title"]
# Out:
# Series([], Name: title, dtype: object)

# %% [markdown]
# #### Q57. Select all titles whose `title` contains the word `"Love"`.

# %%
df.loc[df["title"].str.contains("Love", na=False), "title"]
# Out:
# Series([], Name: title, dtype: object)

# %% [markdown]
# #### Q58. Using `.loc` with a condition, show the `title`, `rating`, and `release_year` of all Movies rated `"R"`.

# %%
df.head(1)
# Out:
#           type             title            director            cast country  \
# show_id
# s1       Movie  The Silent Storm  Guillermo del Toro  Shah Rukh Khan  Mexico
#
#                 date_added  release_year rating duration           listed_in  \
# show_id
# s1       February 11, 2021          1995  TV-14   74 min  Action & Adventure
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...

# %%
df.loc[(df["type"]=="Movie") & (df["rating"]=="R")][["title","rating","release_year"]]
# Out:
#                           title rating  release_year
# show_id
# s4            The Wild Symphony      R          2004
# s7            The Sacred Mirage      R          1993
# s8           The Frozen Kingdom      R          2011
# s14           The Velvet Valley      R          2011
# s19            The Hidden Truth      R          1996
# ...                         ...    ...           ...
# s493      The Rising Chronicles      R          2013
# s501     The Forgotten Frontier      R          2016
# s504        The Midnight Valley      R          2024
# s523           The Lost Whisper      R          2017
# s535           The Eternal Echo      R          2008
#
# [61 rows x 3 columns]

# %% [markdown]
# #### Q59. Count how many Movies were released after 2015 (condition + `len() or `.shape`).

# %%
df.loc[(df["type"] == "Movie") & (df["release_year"] > 2015)].shape
# Out:
# (117, 11)

# %% [markdown]
# #### Q60. Challenge: select all Movies that are from India **or** Nepal and released after 2010 — careful with brackets around the `|` condition!

# %%
df.loc[(df["type"]=="Movie") & ((df["country"]=="India") | (df["country"]=="Nepal")) & (df["release_year"]>2010)][['title','type']]
# Out:
#                       title   type
# show_id
# s47       The Infinite Echo  Movie
# s55      The Velvet Journey  Movie
# s97       The Hidden Mirage  Movie
# s209      The Golden Legacy  Movie
# s276       The Secret Night  Movie
# s397        The Dark Mirage  Movie
# s417       The Golden Night  Movie
# s436      The Sacred Mirage  Movie
# s476      The Wild Frontier  Movie

# %% [markdown]
# ## Section D — Sorting (Q61–Q70)

# %% [markdown]
# #### Q61. Sort the DataFrame by `release_year` ascending. Show the head — what are the oldest titles?

# %%
df.sort_values(by="release_year")
# Out:
#             type                title       director  \
# show_id
# s456       Movie  The Forgotten Storm   Greta Gerwig
# s82      TV Show      The Dark Empire            NaN
# s53      TV Show      The Sacred Echo            NaN
# s310     TV Show      The Hidden Echo            NaN
# s247     TV Show   The Frozen Whisper            NaN
# ...          ...                  ...            ...
# s216     TV Show     The Lost Journey  Takashi Miike
# s510       Movie     The Golden Night      Spike Lee
# s504       Movie  The Midnight Valley            NaN
# s530       Movie    The Endless Truth            NaN
# s533     TV Show  The Silent Protocol  David Fincher
#
#                                                       cast         country  \
# show_id
# s456                                                   NaN  United Kingdom
# s82                                                Zendaya           Japan
# s53                      Mahershala Ali, Timothée Chalamet           Italy
# s310             Denzel Washington, Omar Sy, Javier Bardem           Japan
# s247         Pedro Pascal, Ana de Armas, Leonardo DiCaprio     South Korea
# ...                                                    ...             ...
# s216           Zendaya, Daniel Kaluuya, Scarlett Johansson     South Korea
# s510     Scarlett Johansson, Marion Cotillard, Pedro Pa...          Mexico
# s504                                        Daniel Kaluuya           Japan
# s530                             Tom Hanks, Lupita Nyong'o  United Kingdom
# s533                          Scarlett Johansson, Gong Yoo           Italy
#
#                  date_added  release_year rating   duration  \
# show_id
# s456         April 25, 2016          1990  TV-14    168 min
# s82            May 06, 2016          1990  TV-Y7  6 Seasons
# s53        October 08, 2020          1990   TV-G  5 Seasons
# s310         April 15, 2024          1990  TV-MA  6 Seasons
# s247      February 27, 2021          1990  TV-MA  5 Seasons
# ...                     ...           ...    ...        ...
# s216     September 11, 2019          2024   TV-G  4 Seasons
# s510       October 09, 2022          2024  NC-17    157 min
# s504         April 16, 2023          2024      R    108 min
# s530          June 09, 2023          2024  NC-17     71 min
# s533     September 25, 2023          2024  TV-PG  3 Seasons
#
#                                                  listed_in  \
# show_id
# s456                             Docuseries, Documentaries
# s82                        Thrillers, International Movies
# s53                       International TV Shows, Comedies
# s310                                        Crime TV Shows
# s247     Children & Family Movies, Reality TV, Romantic...
# ...                                                    ...
# s216     Horror Movies, Docuseries, Children & Family M...
# s510          Anime Series, Dramas, International TV Shows
# s504                                        Crime TV Shows
# s530                 Children & Family Movies, TV Comedies
# s533                Dramas, Comedies, International Movies
#
#                                                description
# show_id
# s456     When an unexpected event turns their life upsi...
# s82      In a race against time, a dedicated team unrav...
# s53      When an unexpected event turns their life upsi...
# s310     A humorous and insightful look into modern rel...
# s247     Dark forces emerge as secrets long buried fina...
# ...                                                    ...
# s216     A compelling narrative following characters as...
# s510     Dark forces emerge as secrets long buried fina...
# s504     Dark forces emerge as secrets long buried fina...
# s530     A humorous and insightful look into modern rel...
# s533     When an unexpected event turns their life upsi...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q62. Sort by `release_year` **descending**. Show the 10 newest titles.

# %%
df.sort_values(by="release_year", ascending = False)
# Out:
#             type                 title           director  \
# show_id
# s305       Movie      The Velvet Storm       Greta Gerwig
# s45      TV Show  The Endless Frontier     Anurag Kashyap
# s498       Movie    The Sacred Horizon  Christopher Nolan
# s111       Movie      The Fallen Truth    Martin Scorsese
# s283       Movie     The Shadow Shadow      David Fincher
# ...          ...                   ...                ...
# s247     TV Show    The Frozen Whisper                NaN
# s183       Movie   The Broken Protocol      James Cameron
# s456       Movie   The Forgotten Storm       Greta Gerwig
# s53      TV Show       The Sacred Echo                NaN
# s82      TV Show       The Dark Empire                NaN
#
#                                                       cast         country  \
# show_id
# s305                   Leonardo DiCaprio, Marion Cotillard  United Kingdom
# s45      Florence Pugh, Viola Davis, Tom Hanks, Scarlet...           Japan
# s498                         Tom Hanks, Scarlett Johansson       Australia
# s111                               Tom Hanks, Ana de Armas           Japan
# s283                                                   NaN          Mexico
# ...                                                    ...             ...
# s247         Pedro Pascal, Ana de Armas, Leonardo DiCaprio     South Korea
# s183                                                   NaN          Mexico
# s456                                                   NaN  United Kingdom
# s53                      Mahershala Ali, Timothée Chalamet           Italy
# s82                                                Zendaya           Japan
#
#                 date_added  release_year rating   duration  \
# show_id
# s305        April 05, 2020          2024  PG-13    158 min
# s45                    NaN          2024  TV-14  3 Seasons
# s498      January 19, 2024          2024  TV-MA    121 min
# s111          May 25, 2018          2024      R    134 min
# s283     December 06, 2017          2024  TV-14    142 min
# ...                    ...           ...    ...        ...
# s247     February 27, 2021          1990  TV-MA  5 Seasons
# s183     December 03, 2020          1990  TV-MA    110 min
# s456        April 25, 2016          1990  TV-14    168 min
# s53       October 08, 2020          1990   TV-G  5 Seasons
# s82           May 06, 2016          1990  TV-Y7  6 Seasons
#
#                                                  listed_in  \
# show_id
# s305                  Docuseries, Children & Family Movies
# s45                                               Comedies
# s498                          Comedies, Docuseries, Dramas
# s111     Thrillers, International Movies, TV Action & A...
# s283                      Sci-Fi & Fantasy, Crime TV Shows
# ...                                                    ...
# s247     Children & Family Movies, Reality TV, Romantic...
# s183                                        Crime TV Shows
# s456                             Docuseries, Documentaries
# s53                       International TV Shows, Comedies
# s82                        Thrillers, International Movies
#
#                                                description
# show_id
# s305     A compelling narrative following characters as...
# s45      A heartwarming story of friendship, love, and ...
# s498     An in-depth exploration of human emotions, sec...
# s111     Dark forces emerge as secrets long buried fina...
# s283     A humorous and insightful look into modern rel...
# ...                                                    ...
# s247     Dark forces emerge as secrets long buried fina...
# s183     A humorous and insightful look into modern rel...
# s456     When an unexpected event turns their life upsi...
# s53      When an unexpected event turns their life upsi...
# s82      In a race against time, a dedicated team unrav...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q63. Sort by `title` alphabetically.

# %%
df.sort_values(by="title")
# Out:
#             type                  title           director  \
# show_id
# s542       Movie  The Broken Chronicles       Greta Gerwig
# s93        Movie  The Broken Chronicles      Taika Waititi
# s145       Movie       The Broken Dream   Yorgos Lanthimos
# s18        Movie       The Broken Dream  Quentin Tarantino
# s131       Movie        The Broken Echo                NaN
# ...          ...                    ...                ...
# s4         Movie      The Wild Symphony      David Fincher
# s306     TV Show      The Wild Symphony                NaN
# s253       Movie        The Wild Valley                NaN
# s356     TV Show       The Wild Whisper          Spike Lee
# s472       Movie       The Wild Whisper   Yorgos Lanthimos
#
#                                                       cast         country  \
# show_id
# s542     Mahershala Ali, Priyanka Chopra, Leonardo DiCa...  United Kingdom
# s93                                  Zendaya, Pedro Pascal          Canada
# s145                                         Javier Bardem          Mexico
# s18      Scarlett Johansson, Daniel Kaluuya, Cillian Mu...     South Korea
# s131                                                   NaN  United Kingdom
# ...                                                    ...             ...
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s306                                                   NaN          Canada
# s253                                        Lupita Nyong'o  United Kingdom
# s356     Denzel Washington, Javier Bardem, Scarlett Joh...           Japan
# s472                     Zendaya, Dev Patel, Penélope Cruz           Japan
#
#                 date_added  release_year rating   duration  \
# show_id
# s542     December 29, 2020          2015     PG     79 min
# s93          June 21, 2018          2020      G    117 min
# s145         July 24, 2023          2021  TV-PG    128 min
# s18           May 04, 2021          2023  TV-MA    103 min
# s131       August 20, 2020          2009      R    151 min
# ...                    ...           ...    ...        ...
# s4       November 23, 2015          2004      R    118 min
# s306        April 15, 2021          2017  TV-Y7  2 Seasons
# s253      October 14, 2022          2010      R    167 min
# s356          May 23, 2018          2001  TV-MA  3 Seasons
# s472      October 09, 2024          2001      G     93 min
#
#                                                  listed_in  \
# show_id
# s542        Dramas, Sci-Fi & Fantasy, International Movies
# s93      TV Action & Adventure, Anime Series, Romantic ...
# s145                                           TV Comedies
# s18                                              TV Dramas
# s131                            TV Comedies, Horror Movies
# ...                                                    ...
# s4                               Anime Series, TV Comedies
# s306                                        Crime TV Shows
# s253                         Romantic TV Shows, Docuseries
# s356                                       Romantic Movies
# s472                                      Sci-Fi & Fantasy
#
#                                                description
# show_id
# s542     In a race against time, a dedicated team unrav...
# s93      A humorous and insightful look into modern rel...
# s145     When an unexpected event turns their life upsi...
# s18      When an unexpected event turns their life upsi...
# s131     When an unexpected event turns their life upsi...
# ...                                                    ...
# s4       When an unexpected event turns their life upsi...
# s306     A humorous and insightful look into modern rel...
# s253     A heartwarming story of friendship, love, and ...
# s356     A compelling narrative following characters as...
# s472     A humorous and insightful look into modern rel...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q64. Sort by `release_year` descending AND `title` ascending at the same time (list of columns + list of ascending values).

# %%
df.sort_values(by=["release_year","title"])
# Out:
#             type                title       director  \
# show_id
# s183       Movie  The Broken Protocol  James Cameron
# s82      TV Show      The Dark Empire            NaN
# s285       Movie  The Eternal Promise   Bong Joon-ho
# s456       Movie  The Forgotten Storm   Greta Gerwig
# s247     TV Show   The Frozen Whisper            NaN
# ...          ...                  ...            ...
# s497       Movie  The Silent Frontier            NaN
# s533     TV Show  The Silent Protocol  David Fincher
# s378       Movie    The Velvet Empire   Ridley Scott
# s15        Movie   The Velvet Horizon      Spike Lee
# s305       Movie     The Velvet Storm   Greta Gerwig
#
#                                                       cast         country  \
# show_id
# s183                                                   NaN          Mexico
# s82                                                Zendaya           Japan
# s285     Song Kang-ho, Timothée Chalamet, Omar Sy, Cill...          Brazil
# s456                                                   NaN  United Kingdom
# s247         Pedro Pascal, Ana de Armas, Leonardo DiCaprio     South Korea
# ...                                                    ...             ...
# s497                                 Omar Sy, Ana de Armas         Germany
# s533                          Scarlett Johansson, Gong Yoo           Italy
# s378            Song Kang-ho, Dev Patel, Timothée Chalamet          Mexico
# s15      Scarlett Johansson, Denzel Washington, Penélop...         Germany
# s305                   Leonardo DiCaprio, Marion Cotillard  United Kingdom
#
#                  date_added  release_year rating   duration  \
# show_id
# s183      December 03, 2020          1990  TV-MA    110 min
# s82            May 06, 2016          1990  TV-Y7  6 Seasons
# s285           May 13, 2019          1990      R    175 min
# s456         April 25, 2016          1990  TV-14    168 min
# s247      February 27, 2021          1990  TV-MA  5 Seasons
# ...                     ...           ...    ...        ...
# s497      December 09, 2021          2024  PG-13    142 min
# s533     September 25, 2023          2024  TV-PG  3 Seasons
# s378      February 03, 2016          2024  TV-MA    178 min
# s15          April 25, 2022          2024  PG-13     81 min
# s305         April 05, 2020          2024  PG-13    158 min
#
#                                                  listed_in  \
# show_id
# s183                                        Crime TV Shows
# s82                        Thrillers, International Movies
# s285                                            Docuseries
# s456                             Docuseries, Documentaries
# s247     Children & Family Movies, Reality TV, Romantic...
# ...                                                    ...
# s497               Romantic Movies, Docuseries, Reality TV
# s533                Dramas, Comedies, International Movies
# s378                           Sci-Fi & Fantasy, TV Dramas
# s15                                              Thrillers
# s305                  Docuseries, Children & Family Movies
#
#                                                description
# show_id
# s183     A humorous and insightful look into modern rel...
# s82      In a race against time, a dedicated team unrav...
# s285     A heartwarming story of friendship, love, and ...
# s456     When an unexpected event turns their life upsi...
# s247     Dark forces emerge as secrets long buried fina...
# ...                                                    ...
# s497     A compelling narrative following characters as...
# s533     When an unexpected event turns their life upsi...
# s378     An in-depth exploration of human emotions, sec...
# s15      In a race against time, a dedicated team unrav...
# s305     A compelling narrative following characters as...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q65. Sort by `rating`, and show only `title` and `rating` in the result.

# %%
df.sort_values(by="rating")[["title","rating"]]
# Out:
#                       title rating
# show_id
# s125       The Sacred Storm      G
# s226      The Silent Legacy      G
# s73          The Dark Night      G
# s37       The Silent Mirage      G
# s268         The Lost Heart      G
# ...                     ...    ...
# s500       The Eternal Echo  TV-Y7
# s306      The Wild Symphony  TV-Y7
# s63      The Infinite Truth  TV-Y7
# s31      The Infinite Heart  TV-Y7
# s424      The Fallen Mirage  TV-Y7
#
# [550 rows x 2 columns]

# %% [markdown]
# #### Q66. Sort the **index** using `sort_index()` (useful after filtering).

# %%
df.sort_index()
# Out:
#             type                   title            director  \
# show_id
# s1         Movie        The Silent Storm  Guillermo del Toro
# s10      TV Show     The Silent Symphony                 NaN
# s100       Movie  The Eternal Chronicles                 NaN
# s101     TV Show        The Fallen Dream       Takashi Miike
# s102     TV Show        The Frozen Dream                 NaN
# ...          ...                     ...                 ...
# s95        Movie      The Frozen Kingdom        Greta Gerwig
# s96        Movie        The Lost Whisper        Greta Gerwig
# s97        Movie       The Hidden Mirage       Taika Waititi
# s98        Movie        The Broken Night        Ridley Scott
# s99        Movie         The Rising Echo                 NaN
#
#                                                       cast        country  \
# show_id
# s1                                          Shah Rukh Khan         Mexico
# s10                                                    NaN         France
# s100         Ana de Armas, Priyanka Chopra, Shah Rukh Khan          Italy
# s101                 Mahershala Ali, Meryl Streep, Zendaya          Japan
# s102                                         Javier Bardem         France
# ...                                                    ...            ...
# s95      Denzel Washington, Scarlett Johansson, Penélop...  United States
# s96                                           Meryl Streep          Spain
# s97          Gong Yoo, Viola Davis, Zendaya, Florence Pugh          India
# s98       Leonardo DiCaprio, Cillian Murphy, Margot Robbie    South Korea
# s99            Margot Robbie, Mahershala Ali, Pedro Pascal            NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s10          April 29, 2024          2009  TV-14   1 Season
# s100          June 01, 2015          2008      G     75 min
# s101       October 04, 2023          1993   TV-G  3 Seasons
# s102       October 27, 2020          2007  TV-MA  6 Seasons
# ...                     ...           ...    ...        ...
# s95           June 12, 2019          2022  TV-MA    100 min
# s96           July 22, 2016          2020  TV-PG    148 min
# s97      September 16, 2019          2019      R     84 min
# s98           June 30, 2022          1995  TV-MA     78 min
# s99       November 13, 2018          2005      R    168 min
#
#                                                  listed_in  \
# show_id
# s1                                      Action & Adventure
# s10                                  TV Action & Adventure
# s100                                              Comedies
# s101                            Documentaries, TV Comedies
# s102            Action & Adventure, International TV Shows
# ...                                                    ...
# s95                        Action & Adventure, TV Comedies
# s96                                     Action & Adventure
# s97                              Romantic TV Shows, Dramas
# s98      Romantic TV Shows, Reality TV, TV Action & Adv...
# s99              TV Dramas, International Movies, Comedies
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...
# s10      A compelling narrative following characters as...
# s100     An in-depth exploration of human emotions, sec...
# s101     In a race against time, a dedicated team unrav...
# s102     A heartwarming story of friendship, love, and ...
# ...                                                    ...
# s95      When an unexpected event turns their life upsi...
# s96      A compelling narrative following characters as...
# s97      Dark forces emerge as secrets long buried fina...
# s98      A heartwarming story of friendship, love, and ...
# s99      An in-depth exploration of human emotions, sec...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q67. Show the 5 oldest Movies (filter first, then sort, then head).

# %%
oldest_movies = df.loc[df["type"]=='Movie']
oldest_movies
# Out:
#           type                    title            director  \
# show_id
# s1       Movie         The Silent Storm  Guillermo del Toro
# s2       Movie     The Forgotten Empire       Takashi Miike
# s3       Movie       The Secret Whisper   Quentin Tarantino
# s4       Movie        The Wild Symphony       David Fincher
# s5       Movie         The Secret Storm                 NaN
# ...        ...                      ...                 ...
# s544     Movie       The Midnight Heart  Guillermo del Toro
# s546     Movie         The Silent Dream                 NaN
# s547     Movie   The Forgotten Protocol   Quentin Tarantino
# s548     Movie  The Infinite Chronicles       James Cameron
# s549     Movie         The Rising Truth        Bong Joon-ho
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s544                         Scarlett Johansson, Tom Hanks     South Korea
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
#
#                  date_added  release_year rating duration  \
# show_id
# s1        February 11, 2021          1995  TV-14   74 min
# s2         January 14, 2020          2007  PG-13  167 min
# s3         October 08, 2021          2006  PG-13  163 min
# s4        November 23, 2015          2004      R  118 min
# s5       September 29, 2017          2000  TV-PG  118 min
# ...                     ...           ...    ...      ...
# s544         March 01, 2015          2011      G  157 min
# s546      February 21, 2024          2007  TV-MA   75 min
# s547        August 08, 2022          1998  TV-MA   92 min
# s548      November 29, 2021          1997  NC-17  100 min
# s549      February 18, 2023          2018  TV-MA   87 min
#
#                                                  listed_in  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s544      Action & Adventure, Horror Movies, Documentaries
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...
# s2       An in-depth exploration of human emotions, sec...
# s3       In a race against time, a dedicated team unrav...
# s4       When an unexpected event turns their life upsi...
# s5       Dark forces emerge as secrets long buried fina...
# ...                                                    ...
# s544     A humorous and insightful look into modern rel...
# s546     In a race against time, a dedicated team unrav...
# s547     An in-depth exploration of human emotions, sec...
# s548     A compelling narrative following characters as...
# s549     A heartwarming story of friendship, love, and ...
#
# [397 rows x 11 columns]

# %%
oldest_movies.sort_values(by="release_year")
# Out:
#           type                  title           director  \
# show_id
# s285     Movie    The Eternal Promise       Bong Joon-ho
# s456     Movie    The Forgotten Storm       Greta Gerwig
# s183     Movie    The Broken Protocol      James Cameron
# s51      Movie  The Rising Chronicles    Martin Scorsese
# s329     Movie     The Endless Shadow       Ava DuVernay
# ...        ...                    ...                ...
# s111     Movie       The Fallen Truth    Martin Scorsese
# s490     Movie  The Silent Chronicles       Ava DuVernay
# s498     Movie     The Sacred Horizon  Christopher Nolan
# s510     Movie       The Golden Night          Spike Lee
# s504     Movie    The Midnight Valley                NaN
#
#                                                       cast         country  \
# show_id
# s285     Song Kang-ho, Timothée Chalamet, Omar Sy, Cill...          Brazil
# s456                                                   NaN  United Kingdom
# s183                                                   NaN          Mexico
# s51      Meryl Streep, Gong Yoo, Pedro Pascal, Timothée...   United States
# s329     Denzel Washington, Viola Davis, Dev Patel, Gon...          France
# ...                                                    ...             ...
# s111                               Tom Hanks, Ana de Armas           Japan
# s490                                          Pedro Pascal       Australia
# s498                         Tom Hanks, Scarlett Johansson       Australia
# s510     Scarlett Johansson, Marion Cotillard, Pedro Pa...          Mexico
# s504                                        Daniel Kaluuya           Japan
#
#                 date_added  release_year rating duration  \
# show_id
# s285          May 13, 2019          1990      R  175 min
# s456        April 25, 2016          1990  TV-14  168 min
# s183     December 03, 2020          1990  TV-MA  110 min
# s51          July 24, 2022          1991  NC-17  143 min
# s329     November 12, 2018          1991  NC-17   91 min
# ...                    ...           ...    ...      ...
# s111          May 25, 2018          2024      R  134 min
# s490      January 15, 2022          2024      G  114 min
# s498      January 19, 2024          2024  TV-MA  121 min
# s510      October 09, 2022          2024  NC-17  157 min
# s504        April 16, 2023          2024      R  108 min
#
#                                                  listed_in  \
# show_id
# s285                                            Docuseries
# s456                             Docuseries, Documentaries
# s183                                        Crime TV Shows
# s51                                              Thrillers
# s329                    Anime Series, International Movies
# ...                                                    ...
# s111     Thrillers, International Movies, TV Action & A...
# s490        Children & Family Movies, International Movies
# s498                          Comedies, Docuseries, Dramas
# s510          Anime Series, Dramas, International TV Shows
# s504                                        Crime TV Shows
#
#                                                description
# show_id
# s285     A heartwarming story of friendship, love, and ...
# s456     When an unexpected event turns their life upsi...
# s183     A humorous and insightful look into modern rel...
# s51      In a race against time, a dedicated team unrav...
# s329     In a race against time, a dedicated team unrav...
# ...                                                    ...
# s111     Dark forces emerge as secrets long buried fina...
# s490     Dark forces emerge as secrets long buried fina...
# s498     An in-depth exploration of human emotions, sec...
# s510     Dark forces emerge as secrets long buried fina...
# s504     Dark forces emerge as secrets long buried fina...
#
# [397 rows x 11 columns]

# %%
oldest_movies.head(5)
# Out:
#           type                 title            director  \
# show_id
# s1       Movie      The Silent Storm  Guillermo del Toro
# s2       Movie  The Forgotten Empire       Takashi Miike
# s3       Movie    The Secret Whisper   Quentin Tarantino
# s4       Movie     The Wild Symphony       David Fincher
# s5       Movie      The Secret Storm                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
#
#                  date_added  release_year rating duration  \
# show_id
# s1        February 11, 2021          1995  TV-14   74 min
# s2         January 14, 2020          2007  PG-13  167 min
# s3         October 08, 2021          2006  PG-13  163 min
# s4        November 23, 2015          2004      R  118 min
# s5       September 29, 2017          2000  TV-PG  118 min
#
#                                 listed_in  \
# show_id
# s1                     Action & Adventure
# s2                 International TV Shows
# s3       Romantic TV Shows, Documentaries
# s4              Anime Series, TV Comedies
# s5       Romantic TV Shows, Horror Movies
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...
# s2       An in-depth exploration of human emotions, sec...
# s3       In a race against time, a dedicated team unrav...
# s4       When an unexpected event turns their life upsi...
# s5       Dark forces emerge as secrets long buried fina...

# %% [markdown]
# #### Q68. Show the 5 newest TV Shows.

# %%
new_tvshow = df.loc[df["type"]=='TV Show']
new_tvshow
# Out:
#             type                  title            director  \
# show_id
# s9       TV Show    The Endless Kingdom      Anurag Kashyap
# s10      TV Show    The Silent Symphony                 NaN
# s30      TV Show    The Eternal Journey                 NaN
# s31      TV Show     The Infinite Heart       James Cameron
# s36      TV Show  The Infinite Frontier     Martin Scorsese
# ...          ...                    ...                 ...
# s537     TV Show     The Rising Horizon        Ridley Scott
# s538     TV Show  The Rising Chronicles                 NaN
# s540     TV Show    The Secret Protocol                 NaN
# s545     TV Show    The Eternal Horizon                 NaN
# s550     TV Show       The Velvet Truth  Guillermo del Toro
#
#                                                       cast        country  \
# show_id
# s9                                                     NaN          Japan
# s10                                                    NaN         France
# s30      Timothée Chalamet, Denzel Washington, Zendaya,...         Canada
# s31       Song Kang-ho, Scarlett Johansson, Shah Rukh Khan  United States
# s36         Shah Rukh Khan, Penélope Cruz, Priyanka Chopra    South Korea
# ...                                                    ...            ...
# s537     Tom Hanks, Marion Cotillard, Lupita Nyong'o, D...         Canada
# s538                                                   NaN          Japan
# s540     Viola Davis, Margot Robbie, Denzel Washington,...          Italy
# s545     Viola Davis, Timothée Chalamet, Omar Sy, Ana d...         Canada
# s550                 Timothée Chalamet, Scarlett Johansson  United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s9       September 10, 2020          2002  TV-14  3 Seasons
# s10          April 29, 2024          2009  TV-14   1 Season
# s30         August 26, 2016          1991  TV-MA  2 Seasons
# s31         August 25, 2024          1996  TV-Y7  2 Seasons
# s36       February 06, 2020          2010  TV-PG  4 Seasons
# ...                     ...           ...    ...        ...
# s537                    NaN          1999  TV-Y7   1 Season
# s538      February 13, 2020          2012   TV-G  6 Seasons
# s540        August 07, 2019          2018  TV-14  3 Seasons
# s545          June 07, 2019          2017  TV-MA  2 Seasons
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                          listed_in  \
# show_id
# s9                               Romantic TV Shows
# s10                          TV Action & Adventure
# s30               Action & Adventure, Anime Series
# s31                                     Reality TV
# s36       International TV Shows, Sci-Fi & Fantasy
# ...                                            ...
# s537                     Horror Movies, Reality TV
# s538                     Crime TV Shows, Thrillers
# s540                                    Reality TV
# s545                                 Documentaries
# s550     Horror Movies, Crime TV Shows, Reality TV
#
#                                                description
# show_id
# s9       A humorous and insightful look into modern rel...
# s10      A compelling narrative following characters as...
# s30      In a race against time, a dedicated team unrav...
# s31      In a race against time, a dedicated team unrav...
# s36      A humorous and insightful look into modern rel...
# ...                                                    ...
# s537     An in-depth exploration of human emotions, sec...
# s538     In a race against time, a dedicated team unrav...
# s540     A compelling narrative following characters as...
# s545     An in-depth exploration of human emotions, sec...
# s550     An in-depth exploration of human emotions, sec...
#
# [153 rows x 11 columns]

# %%
new_tvshow.sort_values(by="release_year",ascending = False)
# Out:
#             type                 title           director  \
# show_id
# s45      TV Show  The Endless Frontier     Anurag Kashyap
# s377     TV Show      The Crimson Echo  Quentin Tarantino
# s533     TV Show   The Silent Protocol      David Fincher
# s216     TV Show      The Lost Journey      Takashi Miike
# s143     TV Show     The Lost Protocol                NaN
# ...          ...                   ...                ...
# s424     TV Show     The Fallen Mirage                NaN
# s82      TV Show       The Dark Empire                NaN
# s53      TV Show       The Sacred Echo                NaN
# s310     TV Show       The Hidden Echo                NaN
# s247     TV Show    The Frozen Whisper                NaN
#
#                                                       cast      country  \
# show_id
# s45      Florence Pugh, Viola Davis, Tom Hanks, Scarlet...        Japan
# s377                                                   NaN  South Korea
# s533                          Scarlett Johansson, Gong Yoo        Italy
# s216           Zendaya, Daniel Kaluuya, Scarlett Johansson  South Korea
# s143     Lupita Nyong'o, Tom Hanks, Song Kang-ho, Scarl...        Italy
# ...                                                    ...          ...
# s424                                                   NaN        India
# s82                                                Zendaya        Japan
# s53                      Mahershala Ali, Timothée Chalamet        Italy
# s310             Denzel Washington, Omar Sy, Javier Bardem        Japan
# s247         Pedro Pascal, Ana de Armas, Leonardo DiCaprio  South Korea
#
#                  date_added  release_year rating   duration  \
# show_id
# s45                     NaN          2024  TV-14  3 Seasons
# s377           May 04, 2020          2024  TV-14  4 Seasons
# s533     September 25, 2023          2024  TV-PG  3 Seasons
# s216     September 11, 2019          2024   TV-G  4 Seasons
# s143         March 24, 2020          2024   TV-G  3 Seasons
# ...                     ...           ...    ...        ...
# s424          June 21, 2016          1991  TV-Y7  3 Seasons
# s82            May 06, 2016          1990  TV-Y7  6 Seasons
# s53        October 08, 2020          1990   TV-G  5 Seasons
# s310         April 15, 2024          1990  TV-MA  6 Seasons
# s247      February 27, 2021          1990  TV-MA  5 Seasons
#
#                                                  listed_in  \
# show_id
# s45                                               Comedies
# s377          Crime TV Shows, Docuseries, Sci-Fi & Fantasy
# s533                Dramas, Comedies, International Movies
# s216     Horror Movies, Docuseries, Children & Family M...
# s143                         Sci-Fi & Fantasy, TV Comedies
# ...                                                    ...
# s424                     TV Comedies, International Movies
# s82                        Thrillers, International Movies
# s53                       International TV Shows, Comedies
# s310                                        Crime TV Shows
# s247     Children & Family Movies, Reality TV, Romantic...
#
#                                                description
# show_id
# s45      A heartwarming story of friendship, love, and ...
# s377     When an unexpected event turns their life upsi...
# s533     When an unexpected event turns their life upsi...
# s216     A compelling narrative following characters as...
# s143     A heartwarming story of friendship, love, and ...
# ...                                                    ...
# s424     A humorous and insightful look into modern rel...
# s82      In a race against time, a dedicated team unrav...
# s53      When an unexpected event turns their life upsi...
# s310     A humorous and insightful look into modern rel...
# s247     Dark forces emerge as secrets long buried fina...
#
# [153 rows x 11 columns]

# %%
new_tvshow.head(5)
# Out:
#             type                  title         director  \
# show_id
# s9       TV Show    The Endless Kingdom   Anurag Kashyap
# s10      TV Show    The Silent Symphony              NaN
# s30      TV Show    The Eternal Journey              NaN
# s31      TV Show     The Infinite Heart    James Cameron
# s36      TV Show  The Infinite Frontier  Martin Scorsese
#
#                                                       cast        country  \
# show_id
# s9                                                     NaN          Japan
# s10                                                    NaN         France
# s30      Timothée Chalamet, Denzel Washington, Zendaya,...         Canada
# s31       Song Kang-ho, Scarlett Johansson, Shah Rukh Khan  United States
# s36         Shah Rukh Khan, Penélope Cruz, Priyanka Chopra    South Korea
#
#                  date_added  release_year rating   duration  \
# show_id
# s9       September 10, 2020          2002  TV-14  3 Seasons
# s10          April 29, 2024          2009  TV-14   1 Season
# s30         August 26, 2016          1991  TV-MA  2 Seasons
# s31         August 25, 2024          1996  TV-Y7  2 Seasons
# s36       February 06, 2020          2010  TV-PG  4 Seasons
#
#                                         listed_in  \
# show_id
# s9                              Romantic TV Shows
# s10                         TV Action & Adventure
# s30              Action & Adventure, Anime Series
# s31                                    Reality TV
# s36      International TV Shows, Sci-Fi & Fantasy
#
#                                                description
# show_id
# s9       A humorous and insightful look into modern rel...
# s10      A compelling narrative following characters as...
# s30      In a race against time, a dedicated team unrav...
# s31      In a race against time, a dedicated team unrav...
# s36      A humorous and insightful look into modern rel...

# %% [markdown]
# #### Q69. Sort by `country` and put the missing values **first** (hint: `na_position="first"`).

# %%
df.sort_values(by="country",na_position="first")
# Out:
#             type                title            director  \
# show_id
# s16        Movie     The Secret Dream    Steven Spielberg
# s19        Movie     The Hidden Truth     Pedro Almodóvar
# s99        Movie      The Rising Echo                 NaN
# s120     TV Show  The Crimson Whisper      Alfonso Cuarón
# s187       Movie   The Forgotten Echo        Ridley Scott
# ...          ...                  ...                 ...
# s514     TV Show  The Golden Symphony   Quentin Tarantino
# s150       Movie    The Rising Shadow                 NaN
# s517       Movie   The Crimson Shadow           Sion Sono
# s144     TV Show   The Frozen Promise           Sion Sono
# s550     TV Show     The Velvet Truth  Guillermo del Toro
#
#                                                       cast        country  \
# show_id
# s16                                           Song Kang-ho            NaN
# s19                             Zendaya, Denzel Washington            NaN
# s99            Margot Robbie, Mahershala Ali, Pedro Pascal            NaN
# s120     Florence Pugh, Pedro Pascal, Lupita Nyong'o, A...            NaN
# s187                                           Viola Davis            NaN
# ...                                                    ...            ...
# s514        Daniel Kaluuya, Viola Davis, Denzel Washington  United States
# s150                           Daniel Kaluuya, Viola Davis  United States
# s517     Penélope Cruz, Priyanka Chopra, Scarlett Johan...  United States
# s144                              Tom Hanks, Margot Robbie  United States
# s550                 Timothée Chalamet, Scarlett Johansson  United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s16        October 17, 2023          2019  NC-17    124 min
# s19          April 25, 2021          1996      R    138 min
# s99       November 13, 2018          2005      R    168 min
# s120           May 09, 2022          2004   TV-G   1 Season
# s187      February 16, 2015          2000  TV-PG    114 min
# ...                     ...           ...    ...        ...
# s514      December 24, 2024          1994  TV-14   1 Season
# s150     September 25, 2024          2020  NC-17     75 min
# s517          July 22, 2021          2017  TV-MA    109 min
# s144          June 25, 2017          1999  TV-MA  3 Seasons
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                  listed_in  \
# show_id
# s16      Romantic TV Shows, Docuseries, International M...
# s19                                             Reality TV
# s99              TV Dramas, International Movies, Comedies
# s120                     Docuseries, Thrillers, Reality TV
# s187               Reality TV, Sci-Fi & Fantasy, Thrillers
# ...                                                    ...
# s514                    Comedies, Children & Family Movies
# s150                                      Sci-Fi & Fantasy
# s517     Romantic TV Shows, International Movies, TV Ac...
# s144     TV Action & Adventure, International TV Shows,...
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description
# show_id
# s16      When an unexpected event turns their life upsi...
# s19      An in-depth exploration of human emotions, sec...
# s99      An in-depth exploration of human emotions, sec...
# s120     Dark forces emerge as secrets long buried fina...
# s187     An in-depth exploration of human emotions, sec...
# ...                                                    ...
# s514     A heartwarming story of friendship, love, and ...
# s150     A heartwarming story of friendship, love, and ...
# s517     In a race against time, a dedicated team unrav...
# s144     When an unexpected event turns their life upsi...
# s550     An in-depth exploration of human emotions, sec...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q70. What does `ascending=[False, True]` mean when sorting by two columns? Demonstrate with `release_year` and `title` and explain in a comment.

# %%
df.sort_values(by=["release_year","title"],ascending=[False, True])
# here sorted title must be in ascending order whereas sorted release year is not compulsory to be sort accordingly.
# Out:
#             type                 title           director  \
# show_id
# s377     TV Show      The Crimson Echo  Quentin Tarantino
# s270       Movie     The Crimson Truth          Sion Sono
# s45      TV Show  The Endless Frontier     Anurag Kashyap
# s530       Movie     The Endless Truth                NaN
# s111       Movie      The Fallen Truth    Martin Scorsese
# ...          ...                   ...                ...
# s285       Movie   The Eternal Promise       Bong Joon-ho
# s456       Movie   The Forgotten Storm       Greta Gerwig
# s247     TV Show    The Frozen Whisper                NaN
# s310     TV Show       The Hidden Echo                NaN
# s53      TV Show       The Sacred Echo                NaN
#
#                                                       cast         country  \
# show_id
# s377                                                   NaN     South Korea
# s270     Viola Davis, Priyanka Chopra, Ana de Armas, Ci...           Japan
# s45      Florence Pugh, Viola Davis, Tom Hanks, Scarlet...           Japan
# s530                             Tom Hanks, Lupita Nyong'o  United Kingdom
# s111                               Tom Hanks, Ana de Armas           Japan
# ...                                                    ...             ...
# s285     Song Kang-ho, Timothée Chalamet, Omar Sy, Cill...          Brazil
# s456                                                   NaN  United Kingdom
# s247         Pedro Pascal, Ana de Armas, Leonardo DiCaprio     South Korea
# s310             Denzel Washington, Omar Sy, Javier Bardem           Japan
# s53                      Mahershala Ali, Timothée Chalamet           Italy
#
#                 date_added  release_year rating   duration  \
# show_id
# s377          May 04, 2020          2024  TV-14  4 Seasons
# s270         July 27, 2016          2024      G    103 min
# s45                    NaN          2024  TV-14  3 Seasons
# s530         June 09, 2023          2024  NC-17     71 min
# s111          May 25, 2018          2024      R    134 min
# ...                    ...           ...    ...        ...
# s285          May 13, 2019          1990      R    175 min
# s456        April 25, 2016          1990  TV-14    168 min
# s247     February 27, 2021          1990  TV-MA  5 Seasons
# s310        April 15, 2024          1990  TV-MA  6 Seasons
# s53       October 08, 2020          1990   TV-G  5 Seasons
#
#                                                  listed_in  \
# show_id
# s377          Crime TV Shows, Docuseries, Sci-Fi & Fantasy
# s270     Action & Adventure, TV Action & Adventure, Dramas
# s45                                               Comedies
# s530                 Children & Family Movies, TV Comedies
# s111     Thrillers, International Movies, TV Action & A...
# ...                                                    ...
# s285                                            Docuseries
# s456                             Docuseries, Documentaries
# s247     Children & Family Movies, Reality TV, Romantic...
# s310                                        Crime TV Shows
# s53                       International TV Shows, Comedies
#
#                                                description
# show_id
# s377     When an unexpected event turns their life upsi...
# s270     A humorous and insightful look into modern rel...
# s45      A heartwarming story of friendship, love, and ...
# s530     A humorous and insightful look into modern rel...
# s111     Dark forces emerge as secrets long buried fina...
# ...                                                    ...
# s285     A heartwarming story of friendship, love, and ...
# s456     When an unexpected event turns their life upsi...
# s247     Dark forces emerge as secrets long buried fina...
# s310     A humorous and insightful look into modern rel...
# s53      When an unexpected event turns their life upsi...
#
# [550 rows x 11 columns]

# %% [markdown]
# ## Section E — Updating Data (Q71–Q85)

# %% [markdown]
# #### Q71. Rename the column `listed_in` to `genres` (keep this change).

# %%
df.rename(columns={"listed_in":"genres"},inplace=True)
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
# s550                 Timothée Chalamet, Scarlett Johansson   United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description
# show_id
# s1       When an unexpected event turns their life upsi...
# s2       An in-depth exploration of human emotions, sec...
# s3       In a race against time, a dedicated team unrav...
# s4       When an unexpected event turns their life upsi...
# s5       Dark forces emerge as secrets long buried fina...
# ...                                                    ...
# s546     In a race against time, a dedicated team unrav...
# s547     An in-depth exploration of human emotions, sec...
# s548     A compelling narrative following characters as...
# s549     A heartwarming story of friendship, love, and ...
# s550     An in-depth exploration of human emotions, sec...
#
# [550 rows x 11 columns]

# %% [markdown]
# #### Q72. Create a new column `age_years` = 2026 minus `release_year`.

# %%
df['age_years'] = 2026 - df['release_year']
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
# s550                 Timothée Chalamet, Scarlett Johansson   United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
# [550 rows x 12 columns]

# %% [markdown]
# #### Q73. Create a column `is_movie` that is `True` when `type` is `"Movie"`.

# %%
df["is_movie"] = (df["type"]=='Movie')
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
# s550                 Timothée Chalamet, Scarlett Johansson   United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie
# show_id
# s1           True
# s2           True
# s3           True
# s4           True
# s5           True
# ...           ...
# s546         True
# s547         True
# s548         True
# s549         True
# s550        False
#
# [550 rows x 13 columns]

# %% [markdown]
# #### Q74. Create a column `is_recent` that is `True` when `release_year >= 2020`.

# %%
df["is_recent"] = (df["release_year"] >= 2020)
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
# s550                 Timothée Chalamet, Scarlett Johansson   United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie  is_recent
# show_id
# s1           True      False
# s2           True      False
# s3           True      False
# s4           True      False
# s5           True      False
# ...           ...        ...
# s546         True      False
# s547         True      False
# s548         True      False
# s549         True      False
# s550        False      False
#
# [550 rows x 14 columns]

# %% [markdown]
# #### Q75. Using `.loc` with a condition, set `rating` to `"UNRATED"` for all rows where `rating` is missing.

# %%
df.loc[df["rating"].isna(), "rating"] = "UNRATED"
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...   United States
# s549                                          Song Kang-ho   United States
# s550                 Timothée Chalamet, Scarlett Johansson   United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie  is_recent
# show_id
# s1           True      False
# s2           True      False
# s3           True      False
# s4           True      False
# s5           True      False
# ...           ...        ...
# s546         True      False
# s547         True      False
# s548         True      False
# s549         True      False
# s550        False      False
#
# [550 rows x 14 columns]

# %% [markdown]
# #### Q76. Replace the value `"United States"` with `"USA"` in the `country` column (hint: `replace`).

# %%
df.loc[df["country"]=="United States", "country"] = "USA"
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie  is_recent
# show_id
# s1           True      False
# s2           True      False
# s3           True      False
# s4           True      False
# s5           True      False
# ...           ...        ...
# s546         True      False
# s547         True      False
# s548         True      False
# s549         True      False
# s550        False      False
#
# [550 rows x 14 columns]

# %% [markdown]
# #### Q77. Convert all titles to UPPERCASE into a new column `title_upper` (hint: `str.upper`).

# %%
df['title_upper'] = df['title'].str.upper()
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie  is_recent              title_upper
# show_id
# s1           True      False         THE SILENT STORM
# s2           True      False     THE FORGOTTEN EMPIRE
# s3           True      False       THE SECRET WHISPER
# s4           True      False        THE WILD SYMPHONY
# s5           True      False         THE SECRET STORM
# ...           ...        ...                      ...
# s546         True      False         THE SILENT DREAM
# s547         True      False   THE FORGOTTEN PROTOCOL
# s548         True      False  THE INFINITE CHRONICLES
# s549         True      False         THE RISING TRUTH
# s550        False      False         THE VELVET TRUTH
#
# [550 rows x 15 columns]

# %% [markdown]
# #### Q78. Create a column `title_length` = number of characters in each title (hint: `str.len`).

# %%
df['title_length'] = df['title'].str.len()
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s546       Movie         The Silent Dream                 NaN
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s546                       Leonardo DiCaprio, Song Kang-ho          Canada
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s546      February 21, 2024          2007  TV-MA     75 min
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s546                                       Romantic Movies
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...         31
# s2       An in-depth exploration of human emotions, sec...         19
# s3       In a race against time, a dedicated team unrav...         20
# s4       When an unexpected event turns their life upsi...         22
# s5       Dark forces emerge as secrets long buried fina...         26
# ...                                                    ...        ...
# s546     In a race against time, a dedicated team unrav...         19
# s547     An in-depth exploration of human emotions, sec...         28
# s548     A compelling narrative following characters as...         29
# s549     A heartwarming story of friendship, love, and ...          8
# s550     An in-depth exploration of human emotions, sec...         21
#
#          is_movie  is_recent              title_upper  title_length
# show_id
# s1           True      False         THE SILENT STORM            16
# s2           True      False     THE FORGOTTEN EMPIRE            20
# s3           True      False       THE SECRET WHISPER            18
# s4           True      False        THE WILD SYMPHONY            17
# s5           True      False         THE SECRET STORM            16
# ...           ...        ...                      ...           ...
# s546         True      False         THE SILENT DREAM            16
# s547         True      False   THE FORGOTTEN PROTOCOL            22
# s548         True      False  THE INFINITE CHRONICLES            23
# s549         True      False         THE RISING TRUTH            16
# s550        False      False         THE VELVET TRUTH            16
#
# [550 rows x 16 columns]

# %% [markdown]
# #### Q79. Using `.loc`, change the `title` of the row with index label 0 to `"My Favourite Show"`. Display that row to confirm.

# %%
df.loc[0,"title"] = "My Favourite show"
df.loc[0]
# Out:
# type                          NaN
# title           My Favourite show
# director                      NaN
# cast                          NaN
# country                       NaN
# date_added                    NaN
# release_year                  NaN
# rating                        NaN
# duration                      NaN
# genres                        NaN
# description                   NaN
# age_years                     NaN
# is_movie                      NaN
# is_recent                     NaN
# title_upper                   NaN
# title_length                  NaN
# Name: 0, dtype: object

# %% [markdown]
# #### Q80. Add a column `platform` where every row has the value `"Netflix"`.

# %%
df['platform']= 'Netflix'
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
# 0            NaN        My Favourite show                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
# 0                                                      NaN             NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021        1995.0  TV-14     74 min
# s2         January 14, 2020        2007.0  PG-13    167 min
# s3         October 08, 2021        2006.0  PG-13    163 min
# s4        November 23, 2015        2004.0      R    118 min
# s5       September 29, 2017        2000.0  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s547        August 08, 2022        1998.0  TV-MA     92 min
# s548      November 29, 2021        1997.0  NC-17    100 min
# s549      February 18, 2023        2018.0  TV-MA     87 min
# s550          June 16, 2022        2005.0   TV-G  6 Seasons
# 0                       NaN           NaN    NaN        NaN
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
# 0                                                      NaN
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       31.0
# s2       An in-depth exploration of human emotions, sec...       19.0
# s3       In a race against time, a dedicated team unrav...       20.0
# s4       When an unexpected event turns their life upsi...       22.0
# s5       Dark forces emerge as secrets long buried fina...       26.0
# ...                                                    ...        ...
# s547     An in-depth exploration of human emotions, sec...       28.0
# s548     A compelling narrative following characters as...       29.0
# s549     A heartwarming story of friendship, love, and ...        8.0
# s550     An in-depth exploration of human emotions, sec...       21.0
# 0                                                      NaN        NaN
#
#         is_movie is_recent              title_upper  title_length platform
# show_id
# s1          True     False         THE SILENT STORM          16.0  Netflix
# s2          True     False     THE FORGOTTEN EMPIRE          20.0  Netflix
# s3          True     False       THE SECRET WHISPER          18.0  Netflix
# s4          True     False        THE WILD SYMPHONY          17.0  Netflix
# s5          True     False         THE SECRET STORM          16.0  Netflix
# ...          ...       ...                      ...           ...      ...
# s547        True     False   THE FORGOTTEN PROTOCOL          22.0  Netflix
# s548        True     False  THE INFINITE CHRONICLES          23.0  Netflix
# s549        True     False         THE RISING TRUTH          16.0  Netflix
# s550       False     False         THE VELVET TRUTH          16.0  Netflix
# 0            NaN       NaN                      NaN           NaN  Netflix
#
# [551 rows x 17 columns]

# %% [markdown]
# #### Q81. Delete the column `title_upper` using `drop`.

# %%
df = df.drop('title_upper',axis= 1)
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
# 0            NaN        My Favourite show                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
# 0                                                      NaN             NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021        1995.0  TV-14     74 min
# s2         January 14, 2020        2007.0  PG-13    167 min
# s3         October 08, 2021        2006.0  PG-13    163 min
# s4        November 23, 2015        2004.0      R    118 min
# s5       September 29, 2017        2000.0  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s547        August 08, 2022        1998.0  TV-MA     92 min
# s548      November 29, 2021        1997.0  NC-17    100 min
# s549      February 18, 2023        2018.0  TV-MA     87 min
# s550          June 16, 2022        2005.0   TV-G  6 Seasons
# 0                       NaN           NaN    NaN        NaN
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
# 0                                                      NaN
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       31.0
# s2       An in-depth exploration of human emotions, sec...       19.0
# s3       In a race against time, a dedicated team unrav...       20.0
# s4       When an unexpected event turns their life upsi...       22.0
# s5       Dark forces emerge as secrets long buried fina...       26.0
# ...                                                    ...        ...
# s547     An in-depth exploration of human emotions, sec...       28.0
# s548     A compelling narrative following characters as...       29.0
# s549     A heartwarming story of friendship, love, and ...        8.0
# s550     An in-depth exploration of human emotions, sec...       21.0
# 0                                                      NaN        NaN
#
#         is_movie is_recent  title_length platform
# show_id
# s1          True     False          16.0  Netflix
# s2          True     False          20.0  Netflix
# s3          True     False          18.0  Netflix
# s4          True     False          17.0  Netflix
# s5          True     False          16.0  Netflix
# ...          ...       ...           ...      ...
# s547        True     False          22.0  Netflix
# s548        True     False          23.0  Netflix
# s549        True     False          16.0  Netflix
# s550       False     False          16.0  Netflix
# 0            NaN       NaN           NaN  Netflix
#
# [551 rows x 16 columns]

# %% [markdown]
# #### Q82. Change `release_year` to type `int32` using `astype`. Check with `dtypes`.

# %%
df['release_year'] = df['release_year'].fillna(0).astype('int32')
df.dtypes
# Out:
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int32
# rating           object
# duration         object
# genres           object
# description      object
# age_years       float64
# is_movie         object
# is_recent        object
# title_length    float64
# platform         object
# dtype: object

# %%
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
# 0            NaN        My Favourite show                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
# 0                                                      NaN             NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
# 0                       NaN             0    NaN        NaN
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
# 0                                                      NaN
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       31.0
# s2       An in-depth exploration of human emotions, sec...       19.0
# s3       In a race against time, a dedicated team unrav...       20.0
# s4       When an unexpected event turns their life upsi...       22.0
# s5       Dark forces emerge as secrets long buried fina...       26.0
# ...                                                    ...        ...
# s547     An in-depth exploration of human emotions, sec...       28.0
# s548     A compelling narrative following characters as...       29.0
# s549     A heartwarming story of friendship, love, and ...        8.0
# s550     An in-depth exploration of human emotions, sec...       21.0
# 0                                                      NaN        NaN
#
#         is_movie is_recent  title_length platform
# show_id
# s1          True     False          16.0  Netflix
# s2          True     False          20.0  Netflix
# s3          True     False          18.0  Netflix
# s4          True     False          17.0  Netflix
# s5          True     False          16.0  Netflix
# ...          ...       ...           ...      ...
# s547        True     False          22.0  Netflix
# s548        True     False          23.0  Netflix
# s549        True     False          16.0  Netflix
# s550       False     False          16.0  Netflix
# 0            NaN       NaN           NaN  Netflix
#
# [551 rows x 16 columns]

# %% [markdown]
# #### Q83. Using `.loc` with a condition, create/overwrite a column `era` = `"old"` for titles before 2010 and `"new"` for 2010 onward (two `.loc` assignments, or `np.where`).

# %%
import numpy as np
df['era']= np.where(df['release_year']>2010, 'new','old')
df[['release_year','era']]
df[['title',"release_year","era"]]
# Out:
#                            title  release_year  era
# show_id
# s1              The Silent Storm          1995  old
# s2          The Forgotten Empire          2007  old
# s3            The Secret Whisper          2006  old
# s4             The Wild Symphony          2004  old
# s5              The Secret Storm          2000  old
# ...                          ...           ...  ...
# s547      The Forgotten Protocol          1998  old
# s548     The Infinite Chronicles          1997  old
# s549            The Rising Truth          2018  new
# s550            The Velvet Truth          2005  old
# 0              My Favourite show             0  old
#
# [551 rows x 3 columns]

# %% [markdown]
# #### Q84. Increase `age_years` by 1 for **all** rows in one operation.

# %%
df['age_years']= df['age_years'] + 1
df
# Out:
#             type                    title            director  \
# show_id
# s1         Movie         The Silent Storm  Guillermo del Toro
# s2         Movie     The Forgotten Empire       Takashi Miike
# s3         Movie       The Secret Whisper   Quentin Tarantino
# s4         Movie        The Wild Symphony       David Fincher
# s5         Movie         The Secret Storm                 NaN
# ...          ...                      ...                 ...
# s547       Movie   The Forgotten Protocol   Quentin Tarantino
# s548       Movie  The Infinite Chronicles       James Cameron
# s549       Movie         The Rising Truth        Bong Joon-ho
# s550     TV Show         The Velvet Truth  Guillermo del Toro
# 0            NaN        My Favourite show                 NaN
#
#                                                       cast         country  \
# show_id
# s1                                          Shah Rukh Khan          Mexico
# s2                                          Lupita Nyong'o         Germany
# s3                                                     NaN          France
# s4       Tom Hanks, Lupita Nyong'o, Denzel Washington, ...           Italy
# s5                                                     NaN  United Kingdom
# ...                                                    ...             ...
# s547     Daniel Kaluuya, Priyanka Chopra, Mahershala Al...          Mexico
# s548     Ana de Armas, Pedro Pascal, Scarlett Johansson...             USA
# s549                                          Song Kang-ho             USA
# s550                 Timothée Chalamet, Scarlett Johansson             USA
# 0                                                      NaN             NaN
#
#                  date_added  release_year rating   duration  \
# show_id
# s1        February 11, 2021          1995  TV-14     74 min
# s2         January 14, 2020          2007  PG-13    167 min
# s3         October 08, 2021          2006  PG-13    163 min
# s4        November 23, 2015          2004      R    118 min
# s5       September 29, 2017          2000  TV-PG    118 min
# ...                     ...           ...    ...        ...
# s547        August 08, 2022          1998  TV-MA     92 min
# s548      November 29, 2021          1997  NC-17    100 min
# s549      February 18, 2023          2018  TV-MA     87 min
# s550          June 16, 2022          2005   TV-G  6 Seasons
# 0                       NaN             0    NaN        NaN
#
#                                                     genres  \
# show_id
# s1                                      Action & Adventure
# s2                                  International TV Shows
# s3                        Romantic TV Shows, Documentaries
# s4                               Anime Series, TV Comedies
# s5                        Romantic TV Shows, Horror Movies
# ...                                                    ...
# s547             TV Dramas, Docuseries, Action & Adventure
# s548     International TV Shows, Horror Movies, Action ...
# s549                                   TV Dramas, Comedies
# s550             Horror Movies, Crime TV Shows, Reality TV
# 0                                                      NaN
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       32.0
# s2       An in-depth exploration of human emotions, sec...       20.0
# s3       In a race against time, a dedicated team unrav...       21.0
# s4       When an unexpected event turns their life upsi...       23.0
# s5       Dark forces emerge as secrets long buried fina...       27.0
# ...                                                    ...        ...
# s547     An in-depth exploration of human emotions, sec...       29.0
# s548     A compelling narrative following characters as...       30.0
# s549     A heartwarming story of friendship, love, and ...        9.0
# s550     An in-depth exploration of human emotions, sec...       22.0
# 0                                                      NaN        NaN
#
#         is_movie is_recent  title_length platform  era
# show_id
# s1          True     False          16.0  Netflix  old
# s2          True     False          20.0  Netflix  old
# s3          True     False          18.0  Netflix  old
# s4          True     False          17.0  Netflix  old
# s5          True     False          16.0  Netflix  old
# ...          ...       ...           ...      ...  ...
# s547        True     False          22.0  Netflix  old
# s548        True     False          23.0  Netflix  old
# s549        True     False          16.0  Netflix  new
# s550       False     False          16.0  Netflix  old
# 0            NaN       NaN           NaN  Netflix  old
#
# [551 rows x 17 columns]

# %% [markdown]
# #### Q85. Explain in a markdown comment: why is `df.loc[condition, "col"] = value` the SAFE way to update, instead of `df[condition]["col"] = value`? (SettingWithCopyWarning!)

# %% [markdown]
# ### Using .loc is safe way to update because .loc directly  selects  rows and columns form the dataframe and update them.
#
# ###Another method may not be safe because it may copy instead of modifying which can how error 'SettingWithCopyWarming!'.

# %% [markdown]
# ## Section F — GroupBy (Q86–Q105)

# %% [markdown]
# #### Q86. Group by `type` and count the number of titles in each group (`size()`).

# %%
df.groupby('title').size()
# Out:
# title
# My Favourite show        1
# The Broken Chronicles    2
# The Broken Dream         2
# The Broken Echo          2
# The Broken Empire        1
#                         ..
# The Wild Protocol        1
# The Wild Storm           3
# The Wild Symphony        2
# The Wild Valley          1
# The Wild Whisper         2
# Length: 298, dtype: int64

# %% [markdown]
# #### Q87. Group by `rating` and count titles. Which rating is most common?

# %%
df.groupby('rating').size()
# Out:
# rating
# G        57
# NC-17    44
# PG       48
# PG-13    39
# R        61
# TV-14    70
# TV-G     28
# TV-MA    92
# TV-PG    68
# TV-Y     19
# TV-Y7    24
# dtype: int64

# %%
df.groupby('rating').size().idxmax() # has the most values which is 92.
# Out:
# 'TV-MA'

# %% [markdown]
# #### Q88. Group by `release_year` and count titles. Which year had the most releases?

# %%
df.groupby('release_year').size()
# Out:
# release_year
# 0        1
# 1990     7
# 1991    15
# 1992    11
# 1993    10
# 1994    15
# 1995    12
# 1996    13
# 1997    16
# 1998    11
# 1999    16
# 2000    16
# 2001    14
# 2002    15
# 2003    15
# 2004    24
# 2005    19
# 2006    13
# 2007    17
# 2008    22
# 2009    16
# 2010    15
# 2011    14
# 2012    15
# 2013    16
# 2014    21
# 2015    15
# 2016    18
# 2017    17
# 2018    30
# 2019    12
# 2020    16
# 2021    18
# 2022    12
# 2023    13
# 2024    21
# dtype: int64

# %%
df.groupby('release_year').size().idxmax() # 2018 has the most release which is 30.
# Out:
# np.int32(2018)

# %% [markdown]
# #### Q89. Group by `type` and find the **minimum** and **maximum** `release_year` for each (hint: `agg(["min","max"])`).

# %%
df.groupby('type')['release_year'].agg(["min","max"])
# Out:
#           min   max
# type
# Movie    1990  2024
# TV Show  1990  2024

# %% [markdown]
# #### Q90. Group by `type` and compute the **average** `age_years`.

# %%
df.groupby('type')['age_years'].mean()
# Out:
# type
# Movie      18.523929
# TV Show    19.797386
# Name: age_years, dtype: float64

# %% [markdown]
# #### Q91. Group by `country` and count titles — show only the top 10 (sort + head).

# %%
df.groupby('country').size().sort_values().head(10)
# Out:
# country
# Spain             26
# India             30
# Germany           35
# Australia         36
# Brazil            37
# Canada            40
# South Korea       42
# United Kingdom    42
# France            44
# Japan             44
# dtype: int64

# %% [markdown]
# #### Q92. Group by `rating` and compute the average `title_length`.

# %%
df.groupby('rating')['title_length'].mean()
# Out:
# rating
# G        17.543860
# NC-17    17.136364
# PG       17.791667
# PG-13    17.615385
# R        17.491803
# TV-14    17.628571
# TV-G     17.392857
# TV-MA    17.402174
# TV-PG    17.558824
# TV-Y     17.210526
# TV-Y7    17.500000
# Name: title_length, dtype: float64

# %% [markdown]
# #### Q93. Group by `era` (from Q83) and count Movies vs TV Shows (hint: group by TWO columns).

# %%
df.groupby(['era','type']).size()
# Out:
# era  type
# new  Movie      176
#      TV Show     62
# old  Movie      221
#      TV Show     91
# dtype: int64

# %% [markdown]
# #### Q94. Group by `type` and `rating` together and count. Display the result with `unstack()`.

# %%
df.groupby(['type','rating']).size().unstack()
# Out:
# rating      G  NC-17    PG  PG-13     R  TV-14  TV-G  TV-MA  TV-PG  TV-Y  \
# type
# Movie    57.0   44.0  48.0   39.0  61.0   44.0   NaN   55.0   49.0   NaN
# TV Show   NaN    NaN   NaN    NaN   NaN   26.0  28.0   37.0   19.0  19.0
#
# rating   TV-Y7
# type
# Movie      NaN
# TV Show   24.0

# %% [markdown]
# #### Q95. For Movies only: group by `release_year` and count — how many movies came out each year since 2015? (filter first, then group, then `.tail()`)

# %%
df.groupby('release_year').size().sort_values().tail()
# Out:
# release_year
# 2014    21
# 2024    21
# 2008    22
# 2004    24
# 2018    30
# dtype: int64

# %% [markdown]
# #### Q96. Group by `country` and compute the average `release_year` — which 5 countries have the 'newest' catalogs on average? (sort descending, head)

# %%
a = df.groupby('country')['release_year'].mean()
a.sort_values(ascending = False).head(5)
# Out:
# country
# Germany           2011.714286
# United Kingdom    2011.023810
# USA               2010.224490
# Canada            2010.000000
# Australia         2008.750000
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q97. Use `value_counts()` on `genres` — why does this NOT give clean genre counts? Explain in a comment (hint: multiple genres in one cell).

# %%
df.groupby('genres').value_counts()
# Out:
# genres                                                  type     title                 director            cast                                                   country         date_added         release_year  rating  duration   description                                                                                   age_years  is_movie  is_recent  title_length  platform  era
# Action & Adventure                                      Movie    The Lost Mirage       Greta Gerwig        Florence Pugh, Cillian Murphy                          France          February 10, 2022  2006          TV-PG   102 min    Dark forces emerge as secrets long buried finally come to light in this thrilling drama.      21.0       True      False      15.0          Netflix   old    1
#                                                                  The Lost Protocol     Yorgos Lanthimos    Zendaya                                                Canada          December 31, 2017  2022          TV-14   105 min    An in-depth exploration of human emotions, secrets, and the choices that define us.           5.0        True      True       17.0          Netflix   new    1
#                                                                  The Lost Whisper      Greta Gerwig        Meryl Streep                                           Spain           July 22, 2016      2020          TV-PG   148 min    A compelling narrative following characters as they navigate challenges in a changing world.  7.0        True      True       16.0          Netflix   new    1
#                                                                  The Midnight Whisper  Christopher Nolan   Timothée Chalamet, Priyanka Chopra, Javier Bardem      Italy           February 19, 2018  2007          PG-13   136 min    When an unexpected event turns their life upside down, an unlikely hero must step up.         20.0       True      False      20.0          Netflix   old    1
#                                                                  The Silent Storm      Guillermo del Toro  Shah Rukh Khan                                         Mexico          February 11, 2021  1995          TV-14   74 min     When an unexpected event turns their life upside down, an unlikely hero must step up.         32.0       True      False      16.0          Netflix   old    1
#                                                                                                                                                                                                                                                                                                                                                                                                   ..
# Thrillers, Crime TV Shows, Children & Family Movies     Movie    The Hidden Horizon    Alfonso Cuarón      Ana de Armas, Timothée Chalamet, Priyanka Chopra       Germany         November 18, 2021  2012          G       155 min    Dark forces emerge as secrets long buried finally come to light in this thrilling drama.      15.0       True      False      18.0          Netflix   new    1
# Thrillers, Documentaries                                TV Show  The Forgotten Storm   Martin Scorsese     Timothée Chalamet, Priyanka Chopra                     South Korea     January 18, 2018   2014          TV-G    4 Seasons  When an unexpected event turns their life upside down, an unlikely hero must step up.         13.0       False     False      19.0          Netflix   new    1
# Thrillers, International Movies, TV Action & Adventure  Movie    The Fallen Truth      Martin Scorsese     Tom Hanks, Ana de Armas                                Japan           May 25, 2018       2024          R       134 min    Dark forces emerge as secrets long buried finally come to light in this thrilling drama.      3.0        True      True       16.0          Netflix   new    1
# Thrillers, International TV Shows, Action & Adventure   Movie    The Sacred Mirage     Spike Lee           Gong Yoo, Daniel Kaluuya, Song Kang-ho, Margot Robbie  United Kingdom  January 08, 2016   1993          R       89 min     In a race against time, a dedicated team unravels a mystery that threatens everything.        34.0       True      False      17.0          Netflix   old    1
# Thrillers, Reality TV, Comedies                         Movie    The Wild Horizon      Sion Sono           Shah Rukh Khan, Florence Pugh, Lupita Nyong'o          Italy           July 27, 2022      2021          TV-PG   130 min    In a race against time, a dedicated team unravels a mystery that threatens everything.        6.0        True      True       16.0          Netflix   new    1
# Name: count, Length: 297, dtype: int64

# %% [markdown]
# #### Q98. Group by `is_recent` and count — how many recent vs old titles?

# %%
df['is_recent'].value_counts()
# Out:
# is_recent
# False    470
# True      80
# Name: count, dtype: int64

# %% [markdown]
# #### Q99.Group by `type` and use `.agg()` with a dictionary: count of `title` and mean of `age_years` in ONE command.

# %%
df.groupby("type").agg({
    "title":"count",
    "age_years":"mean"
})
# Out:
#          title  age_years
# type
# Movie      397  18.523929
# TV Show    153  19.797386

# %% [markdown]
# #### Q100. Group by `rating` and show the **number of unique countries** per rating (hint: `nunique`).

# %%
df.groupby("rating")['country'].nunique()
# Out:
# rating
# G        13
# NC-17    13
# PG       12
# PG-13    13
# R        13
# TV-14    13
# TV-G     12
# TV-MA    13
# TV-PG    13
# TV-Y      9
# TV-Y7    11
# Name: country, dtype: int64

# %% [markdown]
# #### Q101. Using `groupby` + `head(1)`, show the FIRST title (by current order) in each `type` group.

# %%
df.groupby('type').head(1)
# Out:
#             type                title            director            cast  \
# show_id
# s1         Movie     The Silent Storm  Guillermo del Toro  Shah Rukh Khan
# s9       TV Show  The Endless Kingdom      Anurag Kashyap             NaN
#
#         country          date_added  release_year rating   duration  \
# show_id
# s1       Mexico   February 11, 2021          1995  TV-14     74 min
# s9        Japan  September 10, 2020          2002  TV-14  3 Seasons
#
#                      genres  \
# show_id
# s1       Action & Adventure
# s9        Romantic TV Shows
#
#                                                description  age_years  \
# show_id
# s1       When an unexpected event turns their life upsi...       32.0
# s9       A humorous and insightful look into modern rel...       25.0
#
#         is_movie is_recent  title_length platform  era
# show_id
# s1          True     False          16.0  Netflix  old
# s9         False     False          19.0  Netflix  old

# %% [markdown]
# #### Q102. Group by `release_year` and count, then plot it with `.plot()` (line chart). What trend do you see?

# %%
df.groupby('release_year')['title'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='release_year,title'>

# %% [markdown]
# #### Q103. Group by `year_added`-style logic isn't possible yet — `date_added` is still text! Group by the **first 4 characters trick is wrong**. Explain in a comment why we need Section G (Cleaning) before we can group by the year a title was ADDED.

# %% [markdown]
# #### Q104. Group by `type` and compute the **median** `release_year`.

# %%
df.groupby('type')['release_year'].median()
# Out:
# type
# Movie      2009.0
# TV Show    2007.0
# Name: release_year, dtype: float64

# %% [markdown]
# #### Q105. Challenge: for each `rating`, what percentage of titles are Movies? (hint: group by rating, compute the mean of `is_movie`, multiply by 100)

# %%
(df.groupby('rating')['is_movie'].mean())*100
# Out:
# rating
# G            100.0
# NC-17        100.0
# PG           100.0
# PG-13        100.0
# R            100.0
# TV-14    62.857143
# TV-G           0.0
# TV-MA    59.782609
# TV-PG    72.058824
# TV-Y           0.0
# TV-Y7          0.0
# Name: is_movie, dtype: object

# %% [markdown]
# ## Section G — Cleaning (Q106–Q125)

# %% [markdown]
# #### Q106. Re-check missing values per column (things changed since Section A!).

# %%
df.isnull().sum()
# Out:
# type              1
# title             0
# director        158
# cast            102
# country          29
# date_added       11
# release_year      0
# rating            1
# duration          1
# genres            1
# description       1
# age_years         1
# is_movie          1
# is_recent         1
# title_length      1
# platform          0
# era               0
# dtype: int64

# %% [markdown]
# #### Q107. Fill missing `director` values with `"Unknown"`.

# %%
df['director']=df['director'].fillna('Unknown')

# %% [markdown]
# #### Q108. Fill missing `cast` values with `"Unknown"`.

# %%
df['cast']=df['cast'].fillna("Unknown")

# %% [markdown]
# #### Q109. Fill missing `country` values with the **most common** country (hint: `mode()[0]`).

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %% [markdown]
# #### Q110. Count the rows where `date_added` is missing, then drop those rows.

# %%
df['date_added'].isna().sum()
df=df.dropna(subset=['date_added'])

# %%
df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# genres          0
# description     0
# age_years       0
# is_movie        0
# is_recent       0
# title_length    0
# platform        0
# era             0
# dtype: int64

# %% [markdown]
# #### Q111. `date_added` has extra spaces in some rows — strip them (hint: `str.strip`).

# %%
 df['date_added'].str.strip()
# Out:
# 0       February 11, 2021
# 1        January 14, 2020
# 2        October 08, 2021
# 3       November 23, 2015
# 4      September 29, 2017
#               ...
# 535     February 21, 2024
# 536       August 08, 2022
# 537     November 29, 2021
# 538     February 18, 2023
# 539         June 16, 2022
# Name: date_added, Length: 540, dtype: object

# %% [markdown]
# #### Q112. Convert `date_added` to datetime with `pd.to_datetime`. Check the dtype after.

# %%
df['date_added']= pd.to_datetime(df['date_added'],errors= "coerce")
print(df['date_added'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# **bold text**#### Q113. NOW create `year_added` = `.dt.year` and `month_added` = `.dt.month_name()`.

# %%
df['year_added']= df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month_name()

print(df[['date_added','year_added','month_added']].head())
# Out:
#   date_added  year_added month_added
# 0 2021-02-11        2021    February
# 1 2020-01-14        2020     January
# 2 2021-10-08        2021     October
# 3 2015-11-23        2015    November
# 4 2017-09-29        2017   September

# %% [markdown]
# #### Q114. Group by `year_added` and count — which year did Netflix add the most content? (This is the question F103 could not answer!)

# %% [markdown]
# #### Q115. Group by `month_added` and count — which month is most popular for adding content?

# %%
months_counts = df.groupby('month_added')['title'].count()
print(months_counts)
# Out:
# month_added
# April        42
# August       52
# December     42
# February     35
# January      37
# July         49
# June         54
# March        39
# May          44
# November     51
# October      46
# September    49
# Name: title, dtype: int64

# %%
months_counts = df.groupby('month_added')['title'].count().idxmax()
print(months_counts)
# Out:
# June

# %% [markdown]
# ### June is most popular month in adding content.

# %% [markdown]
# #### Q116. Look at the `duration` column with `unique()` (first 20 values) — what TWO different formats do you see?

# %%
df['duration'].unique()[:20]
# Out:
# array(['74 min', '167 min', '163 min', '118 min', '120 min', '89 min',
#        '107 min', '3 Seasons', '1 Season', '139 min', '70 min', '170 min',
#        '101 min', '81 min', '124 min', '77 min', '103 min', '138 min',
#        '155 min', '102 min'], dtype=object)

# %% [markdown]
# #### Q117. Extract the number from `duration` into a new column `duration_int` (hint: `str.extract(r"(\\d+)")` then `astype(float)`).

# %%
df['duration_int']= df['duration'].str.extract(r"(\d+)").astype(float)
print(df[['duration','duration_int']].head())
# Out:
#   duration  duration_int
# 0   74 min          74.0
# 1  167 min         167.0
# 2  163 min         163.0
# 3  118 min         118.0
# 4  118 min         118.0

# %% [markdown]
# #### Q118. For Movies only: what is the average, minimum, and maximum duration in minutes?

# %%
print(df[df['type']=="Movie"]['duration_int'].agg(['mean','min','max']))
# Out:
# mean    124.514139
# min      70.000000
# max     180.000000
# Name: duration_int, dtype: float64

# %% [markdown]
# #### Q119. For TV Shows only: how many have more than 5 seasons? Show their titles.

# %%
shows = df[(df['type']=='TV Shows') & (df['duration_int']>5)]
print("Number of shows:" , len(shows))
print(shows['title'])
# Out:
# Number of shows: 0
# Series([], Name: title, dtype: object)

# %% [markdown]
# #### Q120. Check duplicated **titles** (not full rows): are there any titles that appear more than once? Display them.

# %%
df['title'].duplicated(keep=False).sort_values()
# Out:
# 468    False
# 460    False
# 111    False
# 112    False
# 250    False
#        ...
# 196     True
# 194     True
# 193     True
# 190     True
# 539     True
# Name: title, Length: 540, dtype: bool

# %%
duplicates = df[df['title'].duplicated(keep=False)].sort_values('title')

print(duplicates[['title']])
# Out:
#                      title
# 91   The Broken Chronicles
# 531  The Broken Chronicles
# 143       The Broken Dream
# 17        The Broken Dream
# 129        The Broken Echo
# ..                     ...
# 85          The Wild Storm
# 3        The Wild Symphony
# 299      The Wild Symphony
# 348       The Wild Whisper
# 462       The Wild Whisper
#
# [400 rows x 1 columns]

# %% [markdown]
# #### Q121. Are those duplicated titles real duplicates or different shows? Inspect a few with `.loc` and explain in a comment.

# %% [markdown]
#  Q122. The `rating` column contains some WRONG values that are actually durations (like `"74 min"`) — find them (hint: `str.contains("min", na=False)`).

# %%
wrong_value = df[df['rating'].str.contains("min" ,na=False)]
print(wrong_value[['title','rating']])
# Out:
# Empty DataFrame
# Columns: [title, rating]
# Index: []

# %% [markdown]
# #### Q123. Fix those wrong rating rows: set their `rating` to `"UNRATED"` using `.loc`.

# %%
df.loc[df['rating'].str.contains("min", na=False), 'rating'] = "UNRATED"

# %% [markdown]
# #### Q124. Final check: run `info()` and `isna().sum()` — is the dataset clean now? Summarize what you fixed in a comment.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540 entries, 0 to 539
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       540 non-null    object
#  1   type          540 non-null    object
#  2   title         540 non-null    object
#  3   director      540 non-null    object
#  4   cast          540 non-null    object
#  5   country       540 non-null    object
#  6   date_added    540 non-null    datetime64[ns]
#  7   release_year  540 non-null    int32
#  8   rating        540 non-null    object
#  9   duration      540 non-null    object
#  10  genres        540 non-null    object
#  11  description   540 non-null    object
#  12  age_years     540 non-null    float64
#  13  is_movie      540 non-null    object
#  14  is_recent     540 non-null    object
#  15  title_length  540 non-null    float64
#  16  platform      540 non-null    object
#  17  era           540 non-null    object
#  18  year_added    540 non-null    int32
#  19  month_added   540 non-null    object
#  20  duration_int  540 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int32(2), object(15)
# memory usage: 84.5+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2701/1612768228.py in <cell line: 0>()
# ----> 1 df.info().isna().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isna'

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# genres          0
# description     0
# age_years       0
# is_movie        0
# is_recent       0
# title_length    0
# platform        0
# era             0
# year_added      0
# month_added     0
# duration_int    0
# dtype: int64

# %% [markdown]
# #### Q125. Save your cleaned DataFrame to a new file `netflix_clean.csv` (without the index). This file is your submission proof!

# %%
df.to_csv('netflix_clean.csv', index=False)

print("Cleaned file saved as netflix_clean.csv")
# Out:
# Cleaned file saved as netflix_clean.csv

# %% [markdown]
# ---
# ## Submission
# - Answer **all 125 questions** — partial answers get partial marks
# - Run All must work top to bottom without errors (−5 marks if it crashes)
# - Submit BOTH files: `YourName_workbook.ipynb` and `netflix_clean.csv`
